# %% [markdown]
# <FONT size="5.9pt"> **NB2 - PROSPECTIVE CONSEQUENTIAL LCA OF BARK BIOREFINING**
# </FONT>
#
# This Jupyter Notebook was used to conduct an environmental prospective consequential LCA study comparing bark combustion and biorefinery processes (see manuscript). The [*lca_algebraic*](https://link.springer.com/article/10.1007/s11367-021-01993-z) library was used to build the parameterised LCA model; refer to its [documentation](https://github.com/oie-mines-paristech/lca_algebraic/tree/master) for details. Climate impacts were calculated using dynamic characterisation factors from Levasseur et al. (2010) over a 100-year time horizon, based on the ALIGNED guidelines [(Hamelin et al., 2024)](https://zenodo.org/records/10843259). All other impact categories from the ReCiPe 2016 LCIA method were also included.

# %% [markdown]
# # 1. Set-up the directories <a class="anchor" id="section1"></a>
#
# To be able to run the code below, the **working directory (wdir)** needs to be updated based on where the files should be saved on your computer. It is advised to create a new folder in which the Jupyter Notebooks are downloaded from the GitHub repository and saved. A "results" folder will be created to store all outputs of the code (e.g., graphs, tables). This code uploads the ecoinvent database from a local directory. Therefore, a license for the ecoinvent is required and the database should be stored on your computer directly. Consequently, the **database directory (db_dir)** shoud be adapated accordingly. All directories that need to be changed in order to run the code on any computer are highlighted below.

# %%
import os
from shutil import copyfile
import pathlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# define the initial working directory
wdir = '/home/leabraud/Documents/LCAbark' ### DIRECTORY TO BE CHANGED
pdir = os.path.join(wdir,'projects')
print('Working directory:', wdir)

# set the BW project directory
pathlib.Path(pdir).mkdir(parents=True, exist_ok=True)
os.environ['BRIGHTWAY2_DIR'] = pdir
print('Project directory:', os.environ['BRIGHTWAY2_DIR'])

# set the directory to store the results
result_dir = os.path.join(wdir,'results')   
pathlib.Path(result_dir).mkdir(parents=True, exist_ok=True)
print('Results directory:', result_dir)

# set the directory in which the databases are stored
db_dir = '/home/leabraud/Desktop/databases' ### DIRECTORY TO BE CHANGED
print('Database directory:', db_dir)
# Out:
# Working directory: /home/leabraud/Documents/LCAbark
# Project directory: /home/leabraud/Documents/LCAbark/projects
# Results directory: /home/leabraud/Documents/LCAbark/results
# Database directory: /home/leabraud/Desktop/databases

# %% [markdown]
# # 2. Import background databases <a class="anchor" id="section2"></a>
#
# The background databases used in this study correspond to ecoinvent 3.9 consequential and biosphere3. Several versions of the ecoinvent database were generated using the [*premise*](https://www.sciencedirect.com/science/article/pii/S136403212200226X) Python library (see jupyter notebook NB1).

# %%
import lca_algebraic as alg
import brightway2 as bw

# initiate the project / choose project name
alg.initProject('lca_bark') ### NAME OF THE PROJECT CAN BE CHANGED

# import the ecoinvent database from a local directory
alg.importDb("ecoinvent_3.9_conseq", str(db_dir + '/ecoinvent 3.9_consequential_ecoSpold02/datasets')) ## VERSION OF ECOINVENT & DIRECTORY TO BE CHANGED

# overview of the databases
alg.list_databases()
# Out:
# Using environment variable BRIGHTWAY2_DIR for data directory:
# /home/leabraud/Documents/LCAbark/projects
# /tmp/ipykernel_85872/2457968347.py:5: DeprecationWarning: DEPRECATED : Use bw2io.import_ecoinvent_release() instead
#   alg.initProject('lca_bark') ### NAME OF THE PROJECT CAN BE CHANGED
# /tmp/ipykernel_85872/2457968347.py:8: DeprecationWarning: DEPRECATED : Use the new bw2io.import_ecoinvent_release instead
#   alg.importDb("ecoinvent_3.9_conseq", str(db_dir + '/ecoinvent 3.9_consequential_ecoSpold02/datasets')) ## VERSION OF ECOINVENT & DIRECTORY TO BE CHANGED
# [WARNING] Database 'ecoinvent_3.9_conseq' has already been imported
# Biosphere database already present!!! No setup is needed
#                                                    backend  nb_activities  \
# name
# biosphere3                                          sqlite           4709
# ecoinvent_3.9_conseq                                sqlite          18856
# ecoinvent_consequential_3.9_remind_SSP2-PkBudg5...  sqlite          22517
# ecoinvent_consequential_3.9_remind_SSP2-Base_2045   sqlite          22517
# ecoinvent_consequential_3.9_remind_SSP1-PkBudg5...  sqlite          22517
# ecoinvent_consequential_3.9_image_SSP2-Base_2045    sqlite          25105
# Foreground DB                                       sqlite             70
#
#                                                           type
# name
# biosphere3                                           biosphere
# ecoinvent_3.9_conseq                                background
# ecoinvent_consequential_3.9_remind_SSP2-PkBudg5...  background
# ecoinvent_consequential_3.9_remind_SSP2-Base_2045   background
# ecoinvent_consequential_3.9_remind_SSP1-PkBudg5...  background
# ecoinvent_consequential_3.9_image_SSP2-Base_2045    background
# Foreground DB                                       foreground

# %% [markdown]
# # 3. Create foreground databases <a class="anchor" id="section3"></a>

# %%
USER_DB = 'Foreground DB' ## NAME OF THE FOREGROUND DATABASE CAN BE CHANGED
alg.resetDb(USER_DB)
alg.resetParams()
# Out:
# [WARNING] Db Foreground DB was here. Reseting it

# %% [markdown]
# ## 3.1. Get ecoinvent datasets

# %%
# Choose which version of ecoinvent to perform the LCA calculations with
ei = 'ecoinvent_3.9_conseq'
#ei = 'ecoinvent_consequential_3.9_remind_SSP2-PkBudg500_2045'
#ei = 'ecoinvent_consequential_3.9_remind_SSP2-Base_2045'
#ei = 'ecoinvent_consequential_3.9_remind_SSP1-PkBudg500_2045'
#ei = 'ecoinvent_consequential_3.9_image_SSP2-Base_2045'

# %%
# technopshere flows
grid_SE = alg.findActivity(name='market for electricity, high voltage', loc = 'SE', db_name=ei) 
grid_RER = alg.findActivity(name='market group for electricity, high voltage', loc = 'RER', db_name=ei) 
ethylacetate = alg.findActivity(name='ethyl acetate production', loc = 'RER', db_name=ei) 
CO2 = alg.findActivity(name='carbon dioxide production, liquid', loc = 'RER', db_name=ei)
sodiumbicarbonate = alg.findActivity(name='market for sodium bicarbonate', loc = 'GLO', db_name=ei)
sodiumhydroxide = alg.findActivity(name='market for sodium hydroxide, without water, in 50% solution state', loc = 'GLO', db_name=ei)
quicklime = alg.findActivity(name='quicklime production, milled, loose', loc = 'CH', db_name=ei)
wwt = alg.findActivity(name='treatment of wastewater, average, wastewater treatment', loc = 'Europe without Switzerland', db_name=ei)
mw_RER = alg.findActivity(name='market group for municipal solid waste', loc = 'RER', db_name=ei) 
limestone = alg.findActivity(name='market for limestone residue', loc = 'CH', db_name=ei)
heatwoodchips = alg.findActivity(name='heat production, wood chips from industry, at furnace 50kW', loc = 'CH', db_name=ei)

# substituted products
talloil = alg.findActivity(name='tall oil refinery operation', loc = 'GLO', db_name=ei) 
potatostarch = alg.findActivity(name='potato starch production', loc = 'DE', db_name=ei) 
phenol = alg.findActivity(name='phenol production, from cumene', loc = 'RER', db_name=ei)
pulp = alg.findActivity(name='sulfate pulp production, from softwood, unbleached', loc = 'RER', db_name=ei)

# biosphere flows
ethylacetateemission = alg.findActivity(name='Ethyl acetate', db_name='biosphere3', categories = ('air',))
water = alg.findActivity(name='Water, river', db_name='biosphere3', categories = ('natural resource','in water'))
carbondioxide = alg.findActivity(name='Carbon dioxide, fossil', db_name='biosphere3', categories = ('air',))
carbondioxidenonfossil = alg.findActivity(name='Carbon dioxide, non-fossil', db_name='biosphere3', categories = ('air',))

# %% [markdown]
# ## 3.2. Modify the ecoinvent dataset for heat production via cogeneration
#
# The ecoinvent dataset for heat production from wood chips was used to model the environmental burdens of marginal heat supply in both biorefinery configurations. It was also used to calculate the impacts of bark combustion in the combustion scenario and residual biomass combustion in the biorefineries. The dataset was adapted for each specific application (see below).

# %%
# dataset selected in ecoinvent
heat = alg.findActivity(name='heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', loc = 'SE', db_name=ei)

# %% [markdown]
# ### 3.2.1. Combustion of bark
#
# The new dataset "heat_CHP_bark" includes only the impacts associated with the cogeneration process itself, excluding those from wood chip production (assumed similr as bark) and direct non-fossil emissions from wood combustion. The system boundaries exclude bark production (as this process is similar in all three assessed scenarios), while biogenic carbon emissions are accounted for separately. Since the properties of wood chips and bark are similar, it was assumed that combustion processes would result in the same impacts regardless of whether wood chips or bark are used as input.

# %%
heat_CHP_bark = alg.copyActivity(USER_DB, heat, code = 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', withExchanges=True)
heat_CHP_bark.deleteExchanges('Carbon dioxide, non-fossil')
heat_CHP_bark.deleteExchanges('Carbon monoxide, non-fossil')
if ei == 'ecoinvent_3.9_conseq':
    heat_CHP_bark.deleteExchanges('wood chips, wet, measured as dry mass') # for ecoinvent 3.9
else:    
    heat_CHP_bark.deleteExchanges('market for wood chips, wet, measured as dry mass')
#alg.printAct(heat_CHP_bark)

# %% [markdown]
# ### 3.2.2. Burdens from marginal heat production
#
# The unmodified ecoinvent dataset was used as a basis. Here, the objective is to model the heat production from wood chips that would be required to compensate for the heat produced when bark is combusted in the business-as-usual scenario (i.e. combustion scenario). The total amount of heat that would need to be produced for compensation corresponds to the total amount of heat resulting from the combustion of 1 kg DW-eq of bark minus the heat produced via combustion of the residual biomass obtained in the biorefinery. The original process extracted from ecoinvent is not changed since the impacts from wood chips production and combustion are accounted for. The biogenic CO2 and CO from the cogeneration process are not removed. The original activity is simply copied and given a new name for distinction.

# %%
heat_CHP_woodchips = alg.copyActivity(USER_DB, heat, code = 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', withExchanges=True)
# Out:
# [WARNING] Activity 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' was already in 'Foreground DB'. Overwriting it

# %% [markdown]
# ### 3.2.3. Heat production from residual biomass
#
# Again, the same ecoinvent dataset is used as a basis. The amount of residual biomass produced at each processing step is calculated from the mass and carbon balance. The amount of heat produced is calculated using the relation: 1 kg dry mass => 8.5 MJ according to the ecoinvent dataset for heat from cogeneration using wood chips. The same dataset as the one used for heat production from bark is used. No impacts from the biomass and no direct emissions are accounted for. A new name is given for distinction.

# %%
heat_CHP_RB = alg.copyActivity(USER_DB, heat, code = 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', withExchanges=True)
heat_CHP_RB.deleteExchanges('Carbon dioxide, non-fossil')
heat_CHP_RB.deleteExchanges('Carbon monoxide, non-fossil')
if ei == 'ecoinvent_3.9_conseq':
    heat_CHP_RB.deleteExchanges('wood chips, wet, measured as dry mass') # ecoinvent 3.9
else:
    heat_CHP_RB.deleteExchanges('market for wood chips, wet, measured as dry mass')
# Out:
# [WARNING] Activity 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014' was already in 'Foreground DB'. Overwriting it

# %%
# check the climae impacts of heat production using IPCC 2021
ipcc2021 = alg.findMethods('global warming potential (GWP100)', 'IPCC 2021')[0]
climate_impacts_heat_CHP_RB = alg.compute_impacts([heat_CHP_RB],[ipcc2021])
climate_impacts_heat_CHP_RB
# Out:
# [INFO] Db changed recently, clearing cache expr
# [INFO] Db changed recently, clearing cache lcia
#                                                     climate change - global warming potential (GWP100)[kg CO2-Eq]
# heat and power co-generation, wood chips, 6667 ...                                         -0.0142485

# %% [markdown]
# # 4. Create foreground parameters <a class="anchor" id="section4"></a>
#
# ## 4.1. Evaluate the influence of the geographical location
#
# In the sensititvity analysis, the influence of the geographical location on the LCA results is analysed. There are no European market for heat production from cogeneration in the consequential ecoinvent v.3.9 database. However, the dataset exists for many locations. The only differences between the datasets are the electricity mix and the municipal solid waste treatment. Here, both the electricity mix and the waste treatment processes are changed based on the geographical location. List of countries analysed in the sensitivity analysis: SE, NO, FI, DK, FR, DE, BE, LU, NL, AT.

# %%
# SE and RER have already been created above
grid_NO = alg.findActivity(name='market for electricity, high voltage', loc = 'NO', db_name=ei) 
grid_FI = alg.findActivity(name='market for electricity, high voltage', loc = 'FI', db_name=ei) 
grid_DK = alg.findActivity(name='market for electricity, high voltage', loc = 'DK', db_name=ei) 
grid_FR = alg.findActivity(name='market for electricity, high voltage', loc = 'FR', db_name=ei) 
grid_DE = alg.findActivity(name='market for electricity, high voltage', loc = 'DE', db_name=ei) 
grid_BE = alg.findActivity(name='market for electricity, high voltage', loc = 'BE', db_name=ei) 
grid_LU = alg.findActivity(name='market for electricity, high voltage', loc = 'LU', db_name=ei) 
grid_NL = alg.findActivity(name='market for electricity, high voltage', loc = 'NL', db_name=ei) 
grid_AT = alg.findActivity(name='market for electricity, high voltage', loc = 'AT', db_name=ei) 

# RER has already been created above
mw_SE = alg.findActivity(name='market for municipal solid waste', loc = 'SE', db_name=ei) 
mw_NO = alg.findActivity(name='market for municipal solid waste', loc = 'NO', db_name=ei) 
mw_FI = alg.findActivity(name='market for municipal solid waste', loc = 'FI', db_name=ei) 
mw_DK = alg.findActivity(name='market for municipal solid waste', loc = 'DK', db_name=ei) 
mw_FR = alg.findActivity(name='market for municipal solid waste', loc = 'FR', db_name=ei) 
mw_DE = alg.findActivity(name='market for municipal solid waste', loc = 'DE', db_name=ei) 
mw_BE = alg.findActivity(name='market for municipal solid waste', loc = 'BE', db_name=ei) 
mw_LU = alg.findActivity(name='market for municipal solid waste', loc = 'LU', db_name=ei) 
mw_NL = alg.findActivity(name='market for municipal solid waste', loc = 'NL', db_name=ei) 
mw_AT = alg.findActivity(name='market for municipal solid waste', loc = 'AT', db_name=ei)

# %%
# create switch parameter for electricity mix - default value is SE
grid_loc = alg.newEnumParam(
    name = 'grid_loc',
    values = ['grid_SE','grid_NO','grid_FI','grid_DK','grid_FR','grid_DE','grid_BE','grid_LU','grid_NL','grid_AT','grid_RER'],
    default = 'grid_SE',
    #label = 'source of electricity - biorefinery',
    description = "Switch on the source of electricty used in the biorefinery",
    group = 'energy')

# create the virtual activity corresponding to the switch
grid_switch_act = alg.newSwitchAct(dbname = USER_DB,
                                   name = 'grid_switch_act',
                                   paramDef = grid_loc,
                                   acts_dict = {'grid_SE' : grid_SE,
                                                'grid_NO': grid_NO,
                                                'grid_FI': grid_FI,
                                                'grid_DK': grid_DK,
                                                'grid_FR': grid_FR,
                                                'grid_DE': grid_DE,
                                                'grid_BE': grid_BE,
                                                'grid_LU': grid_LU,
                                                'grid_NL': grid_NL,
                                                'grid_AT': grid_AT,
                                                'grid_RER': grid_RER})

# %%
# create switch parameter for municipal solid waste treatment - default value is RER
mw_loc = alg.newEnumParam(
    name = 'mw_loc',
    values = ['mw_SE','mw_NO','mw_FI','mw_DK','mw_FR','mw_DE','mw_BE','mw_LU','mw_NL','mw_AT','mw_RER'],
    default = 'mw_RER',
    #label = 'source of electricity - biorefinery',
    description = "Switch on the source of electricty used in the biorefinery",
    group = 'waste')

# create the virtual activity corresponding to the switch
mw_switch_act = alg.newSwitchAct(dbname = USER_DB,
                                   name = 'mw_switch_act',
                                   paramDef = mw_loc,
                                   acts_dict = {'mw_SE': mw_SE,
                                                'mw_NO': mw_NO,
                                                'mw_FI': mw_FI,
                                                'mw_DK': mw_DK,
                                                'mw_FR': mw_FR,
                                                'mw_DE': mw_DE,
                                                'mw_BE': mw_BE,
                                                'mw_LU': mw_LU,
                                                
                                                'mw_NL': mw_NL,
                                                'mw_AT': mw_AT,
                                                'mw_RER': mw_RER})

# %% [markdown]
# ## 4.2. Evaluate the influence of the percentage of losses
#
# The float parameter defined corresponds to the percentage of biomass losses in the biorefinery processes. An increase in the percentage of losses means that less of the (co)products are produced but more heat is generated from the combustion of residual biomass. The percentage of losses varies between 0 and 30%.

# %%
percentage_losses = alg.newFloatParam(name = "percentage_losses",
                           default = 0, min = 0, max = 1, 
                           unit = '%',
                           group = 'biomass')

# %% [markdown]
# ## 4.3. Evaluate the influence of the integration of the biorefinery with co-located source of energy
#
# The boolean parameter defined changes the amount of electricity used in the biorefinery processes. In the integrated biorefinery (standalone = 0), no external electricity is required and all the energy is supplied from the co-located source which comes into the system free of burdens. In the standalone biorefinery (standalone = 1), the electricity required is supplied by the grid.

# %%
standalone = alg.newBoolParam('standalone', 
                               default = 1, # 1 means the biorefinery system is stand-alone, 0 it is integrated
                               group = 'booleans')

# %% [markdown]
# # 5. Add the parameters to the foreground activities <a class="anchor" id="section5"></a>
#
# ## 5.1. Create parameterised heat production processes
#
# The amount of electricity and municipal solid wastes are not changed, only the geographical location of the datasets.

# %%
heat_CHP_bark.updateExchanges({'electricity*':grid_switch_act})
heat_CHP_bark.updateExchanges({'municipal*':mw_switch_act})

heat_CHP_woodchips.updateExchanges({'electricity*':grid_switch_act})
heat_CHP_woodchips.updateExchanges({'municipal*':mw_switch_act})

heat_CHP_RB.updateExchanges({'electricity*':grid_switch_act})
heat_CHP_RB.updateExchanges({'municipal*':mw_switch_act})

# %% [markdown]
# ## 5.2. Create parameterised biorefinery processes
#
# All the activities are scaled to the functional unit i.e. the processing of 1 kg of bark dry mass.

# %%
# lipophilic extraction from bark
lipophilic_extraction = alg.newActivity(db_name = USER_DB, 
         name = 'lipophilic extraction',
         unit = 'unit',
         exchanges={
             # technosphere inputs
             ethylacetate: 0.002,
             grid_SE: 2.44*standalone,
             # emissions
             ethylacetateemission: 0.002
         })

lipophilic_extraction.updateExchanges({'electricity*':grid_switch_act})
alg.printAct(lipophilic_extraction).to_excel(str(result_dir+'/lipophilic_extraction_'+ei+'.xlsx'))
alg.printAct(lipophilic_extraction)
# Out:
#                                      lipophilic extraction (1.000000 unit)  \
#                                                                      input
# Ethyl acetate                                                Ethyl acetate
# ethyl acetate production                     ethyl acetate production[RER]
# market for electricity, high voltage                   grid_switch_act{FG}
#
#
#                                                amount           unit
# Ethyl acetate                                   0.002       kilogram
# ethyl acetate production                        0.002       kilogram
# market for electricity, high voltage  2.44*standalone  kilowatt hour

# %%
# sugar extraction from lipophilic depleted bark
sugar_extraction = alg.newActivity(db_name = USER_DB, 
 name = 'sugar extraction',
 unit = 'unit',
 exchanges={
     grid_SE: 5*standalone,
     wwt: -0.00007,
     # natural resources
     water: 0.00007
 })

sugar_extraction.updateExchanges({'electricity*':grid_switch_act})
alg.printAct(sugar_extraction).to_excel(str(result_dir+'/sugar_extraction_'+ei+'.xlsx'))
alg.printAct(sugar_extraction)
# Out:
#                                                                      sugar extraction (1.000000 unit)  \
#                                                                                                 input
# Water, river                                                                             Water, river
# market for electricity, high voltage                                              grid_switch_act{FG}
# treatment of wastewater, average, wastewater tr...  treatment of wastewater, average, wastewater t...
#
#                                                                   \
#                                                           amount
# Water, river                                               7e-05
# market for electricity, high voltage                5*standalone
# treatment of wastewater, average, wastewater tr...        -7e-05
#
#
#                                                              unit
# Water, river                                          cubic meter
# market for electricity, high voltage                kilowatt hour
# treatment of wastewater, average, wastewater tr...    cubic meter

# %%
sugar_extraction_withlosses = alg.newActivity(db_name = USER_DB,
                                     name = 'sugar_extraction_withlosses',
                                     unit = 'unit',
                                     exchanges={sugar_extraction:1 # - percentage_losses
                                    })

# %%
# pulping of sugar depleted bark
pulping = alg.newActivity(db_name = USER_DB, 
 name = 'pulping',
 unit = 'unit',
 exchanges={
     sodiumhydroxide: 0.00523,
     quicklime: 0.00629, # calcium oxide
     wwt: -0.00035,
     grid_SE: 1.03*standalone,
     heatwoodchips:0.35,
     CO2: 0.124*standalone,
     limestone:-0.00551,
     # natural resources
     water: 0.00035
 })

pulping.updateExchanges({'electricity*':grid_switch_act})
alg.printAct(pulping).to_excel(str(result_dir+'/pulping_'+ei+'.xlsx'))
alg.printAct(pulping)
# Out:
#                                                                               pulping (1.000000 unit)  \
#                                                                                                 input
# Water, river                                                                             Water, river
# carbon dioxide production, liquid                              carbon dioxide production, liquid[RER]
# heat production, wood chips from industry, at f...  heat production, wood chips from industry, at ...
# market for electricity, high voltage                                              grid_switch_act{FG}
# market for limestone residue                                         market for limestone residue[CH]
# market for sodium hydroxide, without water, in ...  market for sodium hydroxide, without water, in...
# quicklime production, milled, loose                           quicklime production, milled, loose[CH]
# treatment of wastewater, average, wastewater tr...  treatment of wastewater, average, wastewater t...
#
#                                                                       \
#                                                               amount
# Water, river                                                 0.00035
# carbon dioxide production, liquid                   0.124*standalone
# heat production, wood chips from industry, at f...              0.35
# market for electricity, high voltage                 1.03*standalone
# market for limestone residue                                -0.00551
# market for sodium hydroxide, without water, in ...           0.00523
# quicklime production, milled, loose                          0.00629
# treatment of wastewater, average, wastewater tr...          -0.00035
#
#
#                                                              unit
# Water, river                                          cubic meter
# carbon dioxide production, liquid                        kilogram
# heat production, wood chips from industry, at f...      megajoule
# market for electricity, high voltage                kilowatt hour
# market for limestone residue                             kilogram
# market for sodium hydroxide, without water, in ...       kilogram
# quicklime production, milled, loose                      kilogram
# treatment of wastewater, average, wastewater tr...    cubic meter

# %%
pulping_withlosses = alg.newActivity(db_name = USER_DB,
                                     name = 'pulping_withlosses',
                                     unit = 'unit',
                                     exchanges={pulping:1 #- percentage_losses
                                               })

# %%
# production of heat from residual biomass via cogeneration
heat_residues = alg.newActivity(db_name = USER_DB, 
 name = 'heat (RB)',
 unit = 'unit',
 exchanges={
     heat_CHP_RB: 1.53*(1+percentage_losses)
 })
alg.printAct(heat_residues)
# Out:
#                                                                             heat (RB) (1.000000 unit)  \
#                                                                                                 input
# heat and power co-generation, wood chips, 6667 ...  heat and power co-generation, wood chips, 6667...
#
#                                                                                    \
#                                                                            amount
# heat and power co-generation, wood chips, 6667 ...  1.53*percentage_losses + 1.53
#
#
#                                                          unit
# heat and power co-generation, wood chips, 6667 ...  megajoule

# %%
# conversion of lipophilic extractives into tall oil (no impacts assumed)
processA = alg.newActivity(db_name = USER_DB, 
 name = 'process A',
 unit = 'unit',
 exchanges={
 })

# %%
# conversion of sugar extractives into starch (no impacts assumed)
processB = alg.newActivity(db_name = USER_DB, 
 name = 'process B',
 unit = 'unit',
 exchanges={
 })

# %%
# conversion of lignin into phenol (no impacts assumed)
processC = alg.newActivity(db_name = USER_DB, 
 name = 'process C',
 unit = 'unit',
 exchanges={
 })

# %% [markdown]
# ## 5.3. Create parameterised end-of-life processes
#
# The end-of-life (EoL) processes were differentiated for each product and application since the lifespan of the products varies (and will therefore influence the calculation of the climate impacts using dynamic chatacterisation factors). All products are considered to be solid wastes treated by incineration at their EoL. The amount of waste treated depends on the percentage of biomass losses in the biorefinery processes. More losses means that less products are generated and therefore less wastes are treated.

# %% [markdown]
# | Product            | Application          | Share   | Lifespan       | Amount   | Unit |
# |--------------------|----------------------|---------|----------------|----------|------|
# | Pulp               | Biomedical products | 33.33%  | <1 year        | 0.1367   | kg   |
# | Pulp               | Textiles            | 33.33%  | 5 years        | 0.1367   | kg   |
# | Pulp               | Nanocomposites      | 33.33%  | 20 years       | 0.1367   | kg   |
# | Phenol             | Automotive          | 40%     | 13 years       | 0.068    | kg   |
# | Phenol             | Construction        | 23%     | 50 years       | 0.0391   | kg   |
# | Phenol             | Furniture           | 18%     | 15 years       | 0.0306   | kg   |
# | Phenol             | Electronics         | 14%     | 7 years        | 0.0238   | kg   |
# | Phenol             | Others              | 5%      | 21.25 years    | 0.0085   | kg   |
# | Starch             | Cardboard boxes     | 100%    | 1 year         | 0.22     | kg   |
# | Tall oil           | Biofuel             | 100%    | <1 year        | 0.02     | kg   |
# | Residual biomass   | Heat production     | 100%    | <1 year        | 1.52915  | MJ   |

# %%
# treatment of the biorefinery products at their EoL (aggregated value)
# amount corresponds to the mass of the biorefinery products excluding the residues (which are combusted for heat production)
EoL = alg.newActivity(db_name = USER_DB, 
 name = 'EoL',
 unit = 'unit',
 exchanges={
     #mw_RER: -(0.82*(1-percentage_losses))
     mw_RER: -(1-0.18*(1+percentage_losses))
 })
EoL.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL).to_excel(str(result_dir+'/EoL_'+ei+'.xlsx'))
alg.printAct(EoL)
# Out:
#                                        EoL (1.000000 unit)  \
#                                                      input
# market group for municipal solid waste   mw_switch_act{FG}
#
#                                                                        \
#                                                                amount
# market group for municipal solid waste  0.18*percentage_losses - 0.82
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the pulp for biomedical application
EoL_pulp_biomed = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_pulp_biomed',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.3333*0.41*(1-percentage_losses))
                                      mw_RER: -(0.3333*(0.41/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_pulp_biomed.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_pulp_biomed).to_excel(str(result_dir+'/EoL_pulp_biomed_'+ei+'.xlsx'))
alg.printAct(EoL_pulp_biomed)
# Out:
#                                        EoL_pulp_biomed (1.000000 unit)  \
#                                                                  input
# market group for municipal solid waste               mw_switch_act{FG}
#
#                                                                                \
#                                                                        amount
# market group for municipal solid waste  0.029997*percentage_losses - 0.136653
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the pulp for textile application
EoL_pulp_textile = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_pulp_textile',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.3333*0.41*(1-percentage_losses))
                                      mw_RER: -(0.3333*(0.41/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_pulp_textile.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_pulp_textile).to_excel(str(result_dir+'/EoL_pulp_textile_'+ei+'.xlsx'))
alg.printAct(EoL_pulp_textile)
# Out:
#                                        EoL_pulp_textile (1.000000 unit)  \
#                                                                   input
# market group for municipal solid waste                mw_switch_act{FG}
#
#                                                                                \
#                                                                        amount
# market group for municipal solid waste  0.029997*percentage_losses - 0.136653
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the pulp for nanocomposite application
EoL_pulp_nanocomposite = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_pulp_nanocomposite',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.3333*0.41*(1-percentage_losses))
                                      mw_RER: -(0.3333*(0.41/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_pulp_nanocomposite.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_pulp_nanocomposite).to_excel(str(result_dir+'/EoL_pulp_nanocomposite_'+ei+'.xlsx'))
alg.printAct(EoL_pulp_nanocomposite)
# Out:
#                                        EoL_pulp_nanocomposite (1.000000 unit)  \
#                                                                         input
# market group for municipal solid waste                      mw_switch_act{FG}
#
#                                                                                \
#                                                                        amount
# market group for municipal solid waste  0.029997*percentage_losses - 0.136653
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the phenol for automotive application
EoL_phenol_auto = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_phenol_auto',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.4*0.17*(1-percentage_losses))
                                      mw_RER: -(0.4*(0.17/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_phenol_auto.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_phenol_auto).to_excel(str(result_dir+'/EoL_phenol_auto_'+ei+'.xlsx'))
alg.printAct(EoL_phenol_auto)
# Out:
#                                        EoL_phenol_auto (1.000000 unit)  \
#                                                                  input
# market group for municipal solid waste               mw_switch_act{FG}
#
#                                                                                       \
#                                                                               amount
# market group for municipal solid waste  0.0149268292682927*percentage_losses - 0.068
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the phenol for construction application
EoL_phenol_construction = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_phenol_construction',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.23*0.17*(1-percentage_losses))
                                      mw_RER: -(0.23*(0.17/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_phenol_construction.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_phenol_construction).to_excel(str(result_dir+'/EoL_phenol_construction_'+ei+'.xlsx'))
alg.printAct(EoL_phenol_construction)
# Out:
#                                        EoL_phenol_construction (1.000000 unit)  \
#                                                                          input
# market group for municipal solid waste                       mw_switch_act{FG}
#
#                                                                                         \
#                                                                                 amount
# market group for municipal solid waste  0.00858292682926829*percentage_losses - 0.0391
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the phenol for furniture application
EoL_phenol_furniture = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_phenol_furniture',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.18*0.17*(1-percentage_losses))
                                      mw_RER: -(0.18*(0.17/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_phenol_furniture.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_phenol_furniture).to_excel(str(result_dir+'/EoL_phenol_furniture_'+ei+'.xlsx'))
alg.printAct(EoL_phenol_furniture)
# Out:
#                                        EoL_phenol_furniture (1.000000 unit)  \
#                                                                       input
# market group for municipal solid waste                    mw_switch_act{FG}
#
#                                                                                         \
#                                                                                 amount
# market group for municipal solid waste  0.00671707317073171*percentage_losses - 0.0306
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the phenol for electronics application
EoL_phenol_electronics = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_phenol_electronics',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.14*0.17*(1-percentage_losses))
                                      mw_RER: -(0.14*(0.17/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_phenol_electronics.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_phenol_electronics).to_excel(str(result_dir+'/EoL_phenol_electronics_'+ei+'.xlsx'))
alg.printAct(EoL_phenol_electronics)
# Out:
#                                        EoL_phenol_electronics (1.000000 unit)  \
#                                                                         input
# market group for municipal solid waste                      mw_switch_act{FG}
#
#                                                                                         \
#                                                                                 amount
# market group for municipal solid waste  0.00522439024390244*percentage_losses - 0.0238
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the phenol for other applications
EoL_phenol_others = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_phenol_others',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.05*0.17*(1-percentage_losses))
                                      mw_RER: -(0.05*(0.17/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_phenol_others.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_phenol_others).to_excel(str(result_dir+'/EoL_phenol_others_'+ei+'.xlsx'))
alg.printAct(EoL_phenol_others)
# Out:
#                                        EoL_phenol_others (1.000000 unit)  \
#                                                                    input
# market group for municipal solid waste                 mw_switch_act{FG}
#
#                                                                                         \
#                                                                                 amount
# market group for municipal solid waste  0.00186585365853659*percentage_losses - 0.0085
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the phenol for other applications
EoL_starch_cardboard = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_starch_cardboard',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.22*(1-percentage_losses))
                                      mw_RER: -((0.22/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_starch_cardboard.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_starch_cardboard).to_excel(str(result_dir+'/EoL_starch_cardboard_'+ei+'.xlsx'))
alg.printAct(EoL_starch_cardboard)
# Out:
#                                        EoL_starch_cardboard (1.000000 unit)  \
#                                                                       input
# market group for municipal solid waste                    mw_switch_act{FG}
#
#                                                                                      \
#                                                                              amount
# market group for municipal solid waste  0.0482926829268293*percentage_losses - 0.22
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %%
# treatment of the phenol for other applications
EoL_talloil_biofuel = alg.newActivity(db_name = USER_DB,
                                  name = 'EoL_talloil_biofuel',
                                  unit = 'unit',
                                  exchanges={
                                      #mw_RER: -(0.02*(1-percentage_losses))
                                      mw_RER: -((0.02/0.82)*(1-0.18*(1+percentage_losses)))
                                  })
EoL_talloil_biofuel.updateExchanges({'municipal*':mw_switch_act})
alg.printAct(EoL_talloil_biofuel).to_excel(str(result_dir+'/EoL_talloil_biofuel_'+ei+'.xlsx'))
alg.printAct(EoL_talloil_biofuel)
# Out:
#                                        EoL_talloil_biofuel (1.000000 unit)  \
#                                                                      input
# market group for municipal solid waste                   mw_switch_act{FG}
#
#                                                                                       \
#                                                                               amount
# market group for municipal solid waste  0.00439024390243902*percentage_losses - 0.02
#
#
#                                             unit
# market group for municipal solid waste  kilogram

# %% [markdown]
# ## 5.4. Create parameterised substituted processes

# %%
# substitution of tall oil from pine wood (1:1)
talloil_sub = alg.newActivity(db_name = USER_DB,
                             name = 'tall oil (sub.)',
                             unit = 'unit',
                             exchanges = {talloil: - ((0.02/0.82)*(1-0.18*(1+percentage_losses)))})
alg.printAct(talloil_sub)
# Out:
#                             tall oil (sub.) (1.000000 unit)  \
#                                                       input
# tall oil refinery operation     tall oil refinery operation
#
#                                                                            \
#                                                                    amount
# tall oil refinery operation  0.00439024390243902*percentage_losses - 0.02
#
#
#                                  unit
# tall oil refinery operation  kilogram

# %%
# substitution of starch from potato (1:1)
starch_sub = alg.newActivity(db_name = USER_DB,
                          name = 'starch (sub.)',
                          unit = 'unit',
                          exchanges = {potatostarch: -((0.22/0.82)*(1-0.18*(1+percentage_losses)))})
alg.printAct(starch_sub)
# Out:
#                          starch (sub.) (1.000000 unit)  \
#                                                  input
# potato starch production  potato starch production[DE]
#
#                                                                        \
#                                                                amount
# potato starch production  0.0482926829268293*percentage_losses - 0.22
#
#
#                               unit
# potato starch production  kilogram

# %%
# substitution of phenol from cumene (1:1)
phenol_sub = alg.newActivity(db_name = USER_DB,
                            name = 'phenol (sub.)',
                            unit = 'unit',
                            exchanges = {phenol: -((0.17/0.82)*(1-0.18*(1+percentage_losses)))})
alg.printAct(phenol_sub)
# Out:
#                                       phenol (sub.) (1.000000 unit)  \
#                                                               input
# phenol production, from cumene  phenol production, from cumene[RER]
#
#                                                                              \
#                                                                      amount
# phenol production, from cumene  0.0373170731707317*percentage_losses - 0.17
#
#
#                                     unit
# phenol production, from cumene  kilogram

# %%
# substitution of sulfate pulp (1:1)
pulp_sub = alg.newActivity(db_name = USER_DB,
                            name = 'pulp (sub.)',
                            unit = 'unit',
                            exchanges = {pulp: -((0.41/0.82)*(1-0.18*(1+percentage_losses)))})
alg.printAct(pulp_sub)
# Out:
#                                                                           pulp (sub.) (1.000000 unit)  \
#                                                                                                 input
# sulfate pulp production, from softwood, unbleached  sulfate pulp production, from softwood, unblea...
#
#                                                                                    \
#                                                                            amount
# sulfate pulp production, from softwood, unbleached  0.09*percentage_losses - 0.41
#
#
#                                                         unit
# sulfate pulp production, from softwood, unbleached  kilogram

# %%
# environmental impacts from the production of marginal heat in the biorefinery scenarios (e.g., heat that would have been produced by directly burning the bark)
# amount corresponds to the total amount of heat produced when burning bark (8.5 MJ) minus the heat produced from the residues
heat_burdens = alg.newActivity(db_name = USER_DB, 
 name = 'heat (burd.)',
 unit = 'unit',
 exchanges={
     heat_CHP_woodchips: 8.5 -(1.53*(1+percentage_losses))
 })
alg.printAct(heat_burdens)
# Out:
#                                                                          heat (burd.) (1.000000 unit)  \
#                                                                                                 input
# heat and power co-generation, wood chips, 6667 ...  heat and power co-generation, wood chips, 6667...
#
#                                                                                    \
#                                                                            amount
# heat and power co-generation, wood chips, 6667 ...  6.97 - 1.53*percentage_losses
#
#
#                                                          unit
# heat and power co-generation, wood chips, 6667 ...  megajoule

# %% [markdown]
# ## 5.5. Scaled process for combustion scenario

# %%
heat_CHP_bark_scaled = alg.newActivity(db_name = USER_DB,
                                     name = 'heat CHP bark',
                                     unit = 'unit',
                                     exchanges={heat_CHP_bark:8.5})

# %% [markdown]
# # 6. Calculate the indirect CO2-eq emissions from the processes using IPCC 2021
#
# The indirect CO2-eq emissions of bark combustion and biorefinery were calculated using the IPCC 2021 impact assessment method with a time horizon of 100 years. The results obtained were used to calculate the climate impacts of the three scenarios using the dynamic characterisation factors developed by Levasseur et al. (2010).

# %%
# static climate impacts (indirect emissions only) for the stand-alone biorefinery scenario
df_bioref_standalone = alg.compute_impacts([lipophilic_extraction, 
                                            sugar_extraction_withlosses, 
                                            pulping_withlosses, 
                                            heat_burdens, 
                                            #processA, 
                                            #processB, 
                                            #processC, 
                                            heat_residues, 
                                            # EoL
                                            EoL_pulp_biomed,
                                            EoL_pulp_textile, 
                                            EoL_pulp_nanocomposite,
                                            EoL_phenol_auto, 
                                            EoL_phenol_construction, 
                                            EoL_phenol_furniture, 
                                            EoL_phenol_electronics, 
                                            EoL_phenol_others, 
                                            EoL_starch_cardboard, 
                                            EoL_talloil_biofuel,                                   
                                            # substitution
                                            talloil_sub,
                                            starch_sub,
                                            phenol_sub, 
                                            pulp_sub],
                                            # lcia method
                                            [ipcc2021],
                                            # parameters
                                            standalone = 1,
                                            percentage_losses = 0,
                                            grid_loc = 'grid_SE',
                                            mw_loc = 'mw_RER'
                                          )
df_bioref_standalone.to_excel(str(result_dir+"/climate_impacts_IPCC2021_static_standalone_bioref_" + str(ei)+ ".xlsx"))
# Out:
# [INFO] Db changed recently, clearing cache expr
# [INFO] Db changed recently, clearing cache lcia
# [INFO] Db changed recently, clearing cache expr
# [INFO] Db changed recently, clearing cache lcia
# [INFO] Db changed recently, clearing cache expr

# %%
# static climate impacts (indirect emissions only) for the integrated biorefinery scenario
df_bioref_integrated = alg.compute_impacts([lipophilic_extraction, 
                                            sugar_extraction_withlosses, 
                                            pulping_withlosses, 
                                            heat_burdens, 
                                            #processA, 
                                            #processB, 
                                            #processC, 
                                            heat_residues, 
                                            # EoL
                                            EoL_pulp_biomed,
                                            EoL_pulp_textile, 
                                            EoL_pulp_nanocomposite,
                                            EoL_phenol_auto, 
                                            EoL_phenol_construction, 
                                            EoL_phenol_furniture, 
                                            EoL_phenol_electronics, 
                                            EoL_phenol_others, 
                                            EoL_starch_cardboard, 
                                            EoL_talloil_biofuel,                                   
                                            # substitution
                                            talloil_sub,
                                            starch_sub,
                                            phenol_sub, 
                                            pulp_sub],
                                            # lcia method
                                            [ipcc2021],
                                            # parameters
                                            standalone = 0,
                                            percentage_losses = 0,
                                            grid_loc = 'grid_SE',
                                            mw_loc = 'mw_RER'
                                          )
df_bioref_integrated.to_excel(str(result_dir+"/climate_impacts_IPCC2021_static_integrated_bioref_" + str(ei)+ ".xlsx"))

# %%
# static climate impacts (indirect emissions only) for the combustion scenario
df_combustion = alg.compute_impacts([heat_CHP_bark_scaled],
                            [ipcc2021],
                            # parameters
                            percentage_losses = 0,
                            grid_loc = 'grid_SE',
                            mw_loc = 'mw_RER'
                            )
df_combustion.to_excel(str(result_dir+"/climate_impacts_IPCC2021_static_combustion_" + str(ei)+ ".xlsx"))

# %% [markdown]
# ### Check values from the Excel file

# %%
alg.compute_impacts([heat_CHP_bark], [ipcc2021])
# Out:
# [INFO] Required param 'grid_loc' was missing, replacing by default value : grid_SE
# [INFO] Required param 'mw_loc' was missing, replacing by default value : mw_RER
#                                                     climate change - global warming potential (GWP100)[kg CO2-Eq]
# heat and power co-generation, wood chips, 6667 ...                                         -0.0142457

# %%
alg.compute_impacts([heat_CHP_RB],[ipcc2021])
# Out:
# [INFO] Required param 'grid_loc' was missing, replacing by default value : grid_SE
# [INFO] Required param 'mw_loc' was missing, replacing by default value : mw_RER
#                                                     climate change - global warming potential (GWP100)[kg CO2-Eq]
# heat and power co-generation, wood chips, 6667 ...                                         -0.0142457

# %%
# merge the three dataframes
merged_df = pd.concat([df_bioref_standalone, df_bioref_integrated, df_combustion], axis = 1)
# change the name of the columns
merged_df.columns = ['Stand-alone biorefinery', 'Integrated biorefinery', 'Combustion']
# add a column with the EoL years for each process (see main manuscript)
merged_df['Year'] = [35, 35, 35, 35, 35, 36, 40, 55, 48, 85, 50, 42, 56, 36, 36, 35, 35, 35, 35, 35]
merged_df
# Out:
#                              Stand-alone biorefinery  Integrated biorefinery  \
# lipophilic extraction                       0.449329              0.00927422
# sugar_extraction_withlosses                 0.901768              1.6207e-05
# pulping_withlosses                          0.353132                0.034189
# heat (burd.)                              -0.0992929              -0.0992929
# heat (RB)                                  -0.021796               -0.021796
# EoL_pulp_biomed                            0.0523183               0.0523183
# EoL_pulp_textile                           0.0523183               0.0523183
# EoL_pulp_nanocomposite                     0.0523183               0.0523183
# EoL_phenol_auto                            0.0260341               0.0260341
# EoL_phenol_construction                    0.0149696               0.0149696
# EoL_phenol_furniture                       0.0117154               0.0117154
# EoL_phenol_electronics                    0.00911194              0.00911194
# EoL_phenol_others                         0.00325427              0.00325427
# EoL_starch_cardboard                       0.0842281               0.0842281
# EoL_talloil_biofuel                        0.0076571               0.0076571
# tall oil (sub.)                           -0.0366491              -0.0366491
# starch (sub.)                              -0.369547               -0.369547
# phenol (sub.)                              -0.401767               -0.401767
# pulp (sub.)                                0.0279059               0.0279059
# heat CHP bark                                    NaN                     NaN
#
#                              Combustion  Year
# lipophilic extraction               NaN    35
# sugar_extraction_withlosses         NaN    35
# pulping_withlosses                  NaN    35
# heat (burd.)                        NaN    35
# heat (RB)                           NaN    35
# EoL_pulp_biomed                     NaN    36
# EoL_pulp_textile                    NaN    40
# EoL_pulp_nanocomposite              NaN    55
# EoL_phenol_auto                     NaN    48
# EoL_phenol_construction             NaN    85
# EoL_phenol_furniture                NaN    50
# EoL_phenol_electronics              NaN    42
# EoL_phenol_others                   NaN    56
# EoL_starch_cardboard                NaN    36
# EoL_talloil_biofuel                 NaN    36
# tall oil (sub.)                     NaN    35
# starch (sub.)                       NaN    35
# phenol (sub.)                       NaN    35
# pulp (sub.)                         NaN    35
# heat CHP bark                 -0.121089    35

# %% [markdown]
# # 7. Calculate the direct CO2-eq emissions from the bark-based products
#
# The calculation of the direct CO2-eq emissions is based on the carbon balance of the biorefinery (see Supplementary Material 1 and 3). Carbon capture is excluded here since the LCA study is limited to gate-to-gate system boundaries (see manuscript).

# %%
carbon_content_df = pd.read_excel(str(wdir + '/carbon_content.xlsx'), index_col=0)
carbon_content_df
# Out:
#                          Stand-alone biorefinery  Integrated biorefinery  \
# Product
# residual biomass                           62.18                   62.18
# EoL_pulp_biomed                            58.44                   58.44
# EoL_pulp_textile                           58.44                   58.44
# EoL_pulp_nanocomposite                     58.44                   58.44
# EoL_phenol_auto                             60.1                    60.1
# EoL_phenol_construction                    34.56                   34.56
# EoL_phenol_furniture                       27.05                   27.05
# EoL_phenol_electronics                     21.04                   21.04
# EoL_phenol_others                           7.51                    7.51
# EoL_starch_cardboard                       95.97                   95.97
# EoL_talloil_biofuel                         15.2                    15.2
# heat CHP bark                                NaN                     NaN
#
#                          Combustion  Year
# Product
# residual biomass                NaN    35
# EoL_pulp_biomed                 NaN    36
# EoL_pulp_textile                NaN    40
# EoL_pulp_nanocomposite          NaN    55
# EoL_phenol_auto                 NaN    48
# EoL_phenol_construction         NaN    85
# EoL_phenol_furniture            NaN    50
# EoL_phenol_electronics          NaN    42
# EoL_phenol_others               NaN    56
# EoL_starch_cardboard            NaN    36
# EoL_talloil_biofuel             NaN    36
# heat CHP bark                498.95    35

# %%
CO2_emissions_df = carbon_content_df.copy()
CO2_emissions_df['Stand-alone biorefinery'] = CO2_emissions_df['Stand-alone biorefinery']/1000*3.67
CO2_emissions_df['Integrated biorefinery'] = CO2_emissions_df['Integrated biorefinery']/1000*3.67
CO2_emissions_df['Combustion'] = CO2_emissions_df['Combustion']/1000*3.67
CO2_emissions_df
# Out:
#                          Stand-alone biorefinery  Integrated biorefinery  \
# Product
# residual biomass                        0.228201                0.228201
# EoL_pulp_biomed                         0.214475                0.214475
# EoL_pulp_textile                        0.214475                0.214475
# EoL_pulp_nanocomposite                  0.214475                0.214475
# EoL_phenol_auto                         0.220567                0.220567
# EoL_phenol_construction                 0.126835                0.126835
# EoL_phenol_furniture                   0.0992735               0.0992735
# EoL_phenol_electronics                 0.0772168               0.0772168
# EoL_phenol_others                      0.0275617               0.0275617
# EoL_starch_cardboard                     0.35221                 0.35221
# EoL_talloil_biofuel                     0.055784                0.055784
# heat CHP bark                                NaN                     NaN
#
#                          Combustion  Year
# Product
# residual biomass                NaN    35
# EoL_pulp_biomed                 NaN    36
# EoL_pulp_textile                NaN    40
# EoL_pulp_nanocomposite          NaN    55
# EoL_phenol_auto                 NaN    48
# EoL_phenol_construction         NaN    85
# EoL_phenol_furniture            NaN    50
# EoL_phenol_electronics          NaN    42
# EoL_phenol_others               NaN    56
# EoL_starch_cardboard            NaN    36
# EoL_talloil_biofuel             NaN    36
# heat CHP bark               1.83115    35

# %% [markdown]
# # 8. Calculate the climate impacts using dynamic characterisation factors

# %%
from scipy.interpolate import UnivariateSpline

# dynamic characterisation factors for 100 years time horizon developed by Levasseur et al. (2010)
dCF100 = pd.read_excel(str(wdir + '/dynamic_characterisation_factors_Levasseur100.xlsx'))

x = dCF100.index
y = dCF100['CO2_CF']
f = UnivariateSpline(x, y, s=1)

plt.scatter(x, y, marker = '.',label = 'CF CO2 100 years',color = 'black',zorder=1)
plt.plot(x, f(x), '--',lw = 1, label = 'Spline Fit',color = 'red',zorder=2)

plt.legend(frameon=False)
plt.show()

# %% [markdown]
# ## 8.1. Indirect emissions

# %%
# make a copy of the dataframe
dCF_df = merged_df.copy() 
# add a column with the dynamic characterisation factors corresponding to the EoL year
dCF_df['CF_CO2'] = dCF_df.apply(lambda row: f(row['Year']), axis=1)
dCF_df['Stand-alone biorefinery'] = dCF_df['Stand-alone biorefinery']*dCF_df['CF_CO2']
dCF_df['Integrated biorefinery'] = dCF_df['Integrated biorefinery']*dCF_df['CF_CO2']
dCF_df['Combustion'] = dCF_df['Combustion']*dCF_df['CF_CO2']
dCF_df = dCF_df.drop(['Year', 'CF_CO2'], axis=1)
dCF_df.loc['Total']= dCF_df.sum()
dCF_df
# Out:
#                             Stand-alone biorefinery Integrated biorefinery  \
# lipophilic extraction                      0.320012              0.0066051
# sugar_extraction_withlosses                0.642239            1.15426e-05
# pulping_withlosses                         0.251501              0.0243494
# heat (burd.)                             -0.0707164             -0.0707164
# heat (RB)                                -0.0155231             -0.0155231
# EoL_pulp_biomed                           0.0368125              0.0368125
# EoL_pulp_textile                          0.0349991              0.0349991
# EoL_pulp_nanocomposite                    0.0278483              0.0278483
# EoL_phenol_auto                           0.0155569              0.0155569
# EoL_phenol_construction                  0.00314478             0.00314478
# EoL_phenol_furniture                     0.00678555             0.00678555
# EoL_phenol_electronics                   0.00593545             0.00593545
# EoL_phenol_others                        0.00170106             0.00170106
# EoL_starch_cardboard                      0.0592651              0.0592651
# EoL_talloil_biofuel                      0.00538774             0.00538774
# tall oil (sub.)                          -0.0261015             -0.0261015
# starch (sub.)                             -0.263191              -0.263191
# phenol (sub.)                             -0.286139              -0.286139
# pulp (sub.)                               0.0198746              0.0198746
# heat CHP bark                                   NaN                    NaN
# Total                                      0.769392              -0.413394
#
#                             Combustion
# lipophilic extraction              NaN
# sugar_extraction_withlosses        NaN
# pulping_withlosses                 NaN
# heat (burd.)                       NaN
# heat (RB)                          NaN
# EoL_pulp_biomed                    NaN
# EoL_pulp_textile                   NaN
# EoL_pulp_nanocomposite             NaN
# EoL_phenol_auto                    NaN
# EoL_phenol_construction            NaN
# EoL_phenol_furniture               NaN
# EoL_phenol_electronics             NaN
# EoL_phenol_others                  NaN
# EoL_starch_cardboard               NaN
# EoL_talloil_biofuel                NaN
# tall oil (sub.)                    NaN
# starch (sub.)                      NaN
# phenol (sub.)                      NaN
# pulp (sub.)                        NaN
# heat CHP bark               -0.0862396
# Total                       -0.0862396

# %% [markdown]
# ## 8.2. Direct emissions

# %%
dCF_df_direct_emissions = CO2_emissions_df.copy()
# add a column with the dynamic characterisation factors corresponding to the EoL year
dCF_df_direct_emissions['CF_CO2'] = dCF_df_direct_emissions.apply(lambda row: f(row['Year']), axis=1)
dCF_df_direct_emissions['Stand-alone biorefinery'] = dCF_df_direct_emissions['Stand-alone biorefinery']*dCF_df_direct_emissions['CF_CO2']
dCF_df_direct_emissions['Integrated biorefinery'] = dCF_df_direct_emissions['Integrated biorefinery']*dCF_df_direct_emissions['CF_CO2']
dCF_df_direct_emissions['Combustion'] = dCF_df_direct_emissions['Combustion']*dCF_df_direct_emissions['CF_CO2']
dCF_df_direct_emissions = dCF_df_direct_emissions.drop(['Year', 'CF_CO2'], axis=1)
dCF_df_direct_emissions.loc['Total']= dCF_df_direct_emissions.sum()
dCF_df_direct_emissions
# Out:
#                         Stand-alone biorefinery Integrated biorefinery  \
# Product
# residual biomass                       0.162525               0.162525
# EoL_pulp_biomed                         0.15091                0.15091
# EoL_pulp_textile                       0.143476               0.143476
# EoL_pulp_nanocomposite                 0.114162               0.114162
# EoL_phenol_auto                        0.131802               0.131802
# EoL_phenol_construction               0.0266453              0.0266453
# EoL_phenol_furniture                  0.0574994              0.0574994
# EoL_phenol_electronics                0.0502984              0.0502984
# EoL_phenol_others                     0.0144069              0.0144069
# EoL_starch_cardboard                   0.247824               0.247824
# EoL_talloil_biofuel                   0.0392511              0.0392511
# heat CHP bark                               NaN                    NaN
# Total                                    1.1388                 1.1388
#
#                         Combustion
# Product
# residual biomass               NaN
# EoL_pulp_biomed                NaN
# EoL_pulp_textile               NaN
# EoL_pulp_nanocomposite         NaN
# EoL_phenol_auto                NaN
# EoL_phenol_construction        NaN
# EoL_phenol_furniture           NaN
# EoL_phenol_electronics         NaN
# EoL_phenol_others              NaN
# EoL_starch_cardboard           NaN
# EoL_talloil_biofuel            NaN
# heat CHP bark              1.30414
# Total                      1.30414

# %% [markdown]
# ## 8.3. Total climate impacts

# %%
# aggregate the EoL values into a unique row
total_df = dCF_df.copy()
total_df.loc['EoL']= total_df.iloc[5:15].sum()
total_df_vf = total_df.drop(total_df.index[5:15])

# move the EoL row up
total_df_vf = total_df_vf.drop(['Total'])
row_to_move = total_df_vf.iloc[[10]]
total_df_vf = total_df_vf.drop(['EoL'])
total_df_vf = pd.concat([total_df_vf.iloc[:5], row_to_move, total_df_vf.iloc[5:]])

## add a row from the direct CO2 emissions (biogenic)
total_df_vf.loc['direct CO2'] = dCF_df_direct_emissions.loc['Total']

#change index labels
index_labels = ['lipophilic extraction', 'sugar extraction', 'pulping', 'heat (burd.)', 'heat (RB)','EoL', 
                'tall oil (sub.)', 'starch (sub.)', 'phenol (sub.)', 'pulp (sub.)', 'heat CHP bark', 'biogenic CO2']
total_df_vf.index = index_labels
total_df_vf.rename(columns={'Stand-alone biorefinery': 'Stand-alone\nbiorefinery', 'Integrated biorefinery': 'Integrated\nbiorefinery'}, inplace=True)
#total_df_vf.loc['Total']= total_df_vf.sum()
total_df_vf.to_excel(str(result_dir+'/total_climate_impacts_DCFs_' + ei +'.xlsx')) 
total_df_vf
# Out:
#                       Stand-alone\nbiorefinery Integrated\nbiorefinery  \
# lipophilic extraction                 0.320012               0.0066051
# sugar extraction                      0.642239             1.15426e-05
# pulping                               0.251501               0.0243494
# heat (burd.)                        -0.0707164              -0.0707164
# heat (RB)                           -0.0155231              -0.0155231
# EoL                                   0.197436                0.197436
# tall oil (sub.)                     -0.0261015              -0.0261015
# starch (sub.)                        -0.263191               -0.263191
# phenol (sub.)                        -0.286139               -0.286139
# pulp (sub.)                          0.0198746               0.0198746
# heat CHP bark                              NaN                     NaN
# biogenic CO2                            1.1388                  1.1388
#
#                       Combustion
# lipophilic extraction        NaN
# sugar extraction             NaN
# pulping                      NaN
# heat (burd.)                 NaN
# heat (RB)                    NaN
# EoL                            0
# tall oil (sub.)              NaN
# starch (sub.)                NaN
# phenol (sub.)                NaN
# pulp (sub.)                  NaN
# heat CHP bark         -0.0862396
# biogenic CO2             1.30414

# %%
# color palette from: https://davidmathlogic.com/colorblind/#%23332288-%23117733-%2344AA99-%2388CCEE-%23DDCC77-%23CC6677-%23AA4499-%23882255
colors = ['#DDCC77', # LE yellow
          '#88CCEE', # SE sky blue
          '#332288', # P dark blue
          '#fff0db', # heat (RB) beige
          'black', # heat burd. black
          '#882255',# EoL red wine
          '#D3D3D3', #tall oil sub.light grey
          '#44AA99', # starch sub. teal
          '#117733', # phenol sub. dark green 
          '#AA4499', # pulp sub.plum pink
          'grey', # heat CHP bark dark grey
          '#CC6677', # biogenic C orange pink          
]

# %%
# GWP scores with substitution
GWP_scores_ei39 = list(total_df_vf.sum())
GWP_scores_ei39 = ['%.2f' % elem for elem in GWP_scores_ei39]
GWP_scores_ei39 = [float(elem) for elem in GWP_scores_ei39] # the list items must be floats
GWP_scores_ei39

# GWP scores without substitution
df_wo_subst_ei39 = total_df_vf.drop(['heat (burd.)', 'tall oil (sub.)', 'starch (sub.)', 'phenol (sub.)', 'pulp (sub.)'])
GWP_scores_wo_subst_ei39 = list(df_wo_subst_ei39.sum())
GWP_scores_wo_subst_ei39 = ['%.2f' % elem for elem in GWP_scores_wo_subst_ei39]
GWP_scores_wo_subst_ei39 = [float(elem) for elem in GWP_scores_wo_subst_ei39] # the list items must be floats
GWP_scores_wo_subst_ei39

# transpose the dataframe
df_transposed = total_df_vf.T

fig, ax = plt.subplots(figsize=(7, 7))

ax.set_ylim(-0.7,3.0)

col_names = ['Stand-alone\nbiorefinery', 'Integrated\nbiorefinery', 'Combustion']

bars = df_transposed.plot(kind='bar', stacked=True, ax=ax, color=colors,legend = False, width=0.5)
ax.set_ylabel('Climate impacts (kg CO2-eq/FU)', fontsize=14)
#ax.legend(loc='lower center', bbox_to_anchor=(0.55, 0.7), title_fontsize='12', fontsize='14', ncol=2, frameon = False)

ax.tick_params(axis='x', labelsize=14, rotation=0)
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(axis='x', which='both', bottom=False)  # Remove x-axis ticks

ax.axhline(y=0, color='black', linestyle='-', linewidth=0.5)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# add the single GWP100 scores for each scenario
categories_index = np.arange(len(col_names))
ax.scatter(categories_index, GWP_scores_wo_subst_ei39, color='black', marker = '^', zorder=5)
ax.scatter(categories_index, GWP_scores_ei39, color='black', marker = 'H', zorder=5)

for i, val in enumerate(GWP_scores_ei39):
    ax.text(categories_index[i], val - 0.12, f'{val}', ha='center', color='black',va = 'top', fontsize=14)

for i, val in enumerate(GWP_scores_wo_subst_ei39):
    ax.text(categories_index[i], val+0.12, f'{val}', ha='center', color='black',va = 'bottom', fontsize=14)

# +/- 0.08

plt.tight_layout()

#plt.savefig(str(result_dir+'/fig5_DCFs_results_' + ei + '.pdf'), dpi=300)
plt.savefig(str(result_dir+'/fig5_DCFs_results_'+ei+'.pdf'), dpi=300)

plt.show()

# %% [markdown]
# # 9. Sensitivity analysis on climate change

# %% [markdown]
# ## 9.1. Influence of the product's lifespan
#
# The product's lifespan influences the calculation of the climate impacts through the choice of dynamic characterisation factors. Here, the losses of biomass are fixed to 0 as well as the biogenic carbon content of bark and the amount of CO2-eq emitted (i.e. one-at-a-time sensitivity analysis). Both the direct and indirect emissions are affected by a change in the dynamic CFs. The maximum lifespan is fixed at 100 years.

# %%
def climate_impacts(indirect_emissions_df, direct_emissions_df, percentage_change_list):
    
    total_climate_impact_standalone = []
    total_climate_impact_integrated = []
    total_climate_impact_combustion = []    

    for value in percentage_change_list:

        df_indirect = indirect_emissions_df.copy()
        df_direct = direct_emissions_df.copy()

        # in the two dataframe, change the "Year" value to account for the percentage of change
        df_indirect['Year'] = df_indirect['Year'] + df_indirect['Year']*value
        df_direct['Year'] = df_direct['Year'] + df_direct['Year']*value

        # if the updated year exceeds 100, set it to the max = 100 years
        for i in range(len(df_direct['Year'].values)):
            if df_direct['Year'].values[i]>100:
                df_direct['Year'].values[i]=100

        for i in range(len(df_indirect['Year'].values)):
            if df_indirect['Year'].values[i]>100:
                df_indirect['Year'].values[i]=100
        
        # calculate the climate impacts based on the indirect emissions
        df_indirect['CF_CO2'] = df_indirect.apply(lambda row: f(row['Year']), axis=1)
        df_indirect['Stand-alone biorefinery'] = df_indirect['Stand-alone biorefinery']*df_indirect['CF_CO2']
        df_indirect['Integrated biorefinery'] = df_indirect['Integrated biorefinery']*df_indirect['CF_CO2']
        df_indirect['Combustion'] = df_indirect['Combustion']*df_indirect['CF_CO2']
    
        # calculate the climate impacts based on the direct emissions
        df_direct['CF_CO2'] = df_direct.apply(lambda row: f(row['Year']), axis=1)
        df_direct['Stand-alone biorefinery'] = df_direct['Stand-alone biorefinery']*df_direct['CF_CO2']
        df_direct['Integrated biorefinery'] = df_direct['Integrated biorefinery']*df_direct['CF_CO2']
        df_direct['Combustion'] = df_direct['Combustion']*df_direct['CF_CO2']
    
        # calculate the total climate impacts
        total_climate_impact_standalone.append(df_indirect['Stand-alone biorefinery'].sum() + df_direct['Stand-alone biorefinery'].sum())
        total_climate_impact_integrated.append(df_indirect['Integrated biorefinery'].sum() + df_direct['Integrated biorefinery'].sum())
        total_climate_impact_combustion.append(df_indirect['Combustion'].sum() + df_direct['Combustion'].sum())

    return total_climate_impact_standalone, total_climate_impact_integrated, total_climate_impact_combustion

# %%
# check the values using the baseline 0% of change in the lifespan
#test_standalone, test_integrated, test_combustion= climate_impacts(indirect_emissions_df, direct_emissions_df, [0])
#print('For 0 percentage of lifespan change (i.e. baseline), the values obtained are: \nStand-alone: %s kg CO2-eq, Integrated: %s kg CO2-eq, and Combustion: %s kg CO2-eq' %(test_standalone[0], test_integrated[0], test_combustion[0]))

# %%
percentage_change_list = np.arange(-0.3, 0.3,0.01).tolist()
indirect_emissions_df = merged_df
direct_emissions_df = CO2_emissions_df

total_climate_impact_standalone, total_climate_impact_integrated, total_climate_impact_combustion= climate_impacts(indirect_emissions_df, direct_emissions_df, percentage_change_list)

# %%
import matplotlib.pyplot as plt

# Plotting the data
fig, ax = plt.subplots(figsize=(7, 5))

# Plot continuous lines
plt.plot(percentage_change_list, total_climate_impact_standalone, 
         label='Stand-alone biorefinery', color='#332288', linestyle='-', linewidth=3.5)
plt.plot(percentage_change_list, total_climate_impact_integrated, 
         label='Integrated biorefinery', color='#44AA99', linestyle='-', linewidth=3.5)
plt.plot(percentage_change_list, total_climate_impact_combustion, 
         label='Combustion', color='#CC6677', linestyle='-', linewidth=3.5)

# Adding titles and labels
plt.xlabel('Change of lifespan (%)', size=14)
plt.ylabel('Climate impacts (kg CO2-eq/FU)', size=14)
plt.legend(frameon=False, fontsize=14, loc='lower center', bbox_to_anchor=(0.27, 0.5))

# Customize axes
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='x', labelsize=14, rotation=0)
ax.tick_params(axis='y', labelsize=14)

# Save and show plot
plt.tight_layout()
plt.savefig(str(result_dir+'/fig6_sensitivity_lifespan_'+ei+'.pdf'), dpi=300)

plt.show()

# %% [markdown]
# ## 9.2. Influence of the geographical location
#
# The change of geographical location influences the indirect emissions from the biorefinery and combustion scneario only. In this model, the direct emissions remain similar, no matter the geographical location. The percentage of losses is fixed to 0.

# %%
def sensitivity_geoloc (list_processes, index_labels, countries, standalone):

    # create the initial dataframe with the index
    merged_df = pd.DataFrame({'grid_loc': ['grid_SE', 'grid_NO', 'grid_FI', 'grid_DK', 'grid_FR', 'grid_DE', 'grid_BE', 'grid_LU', 'grid_NL', 'grid_AT', 'grid_RER']})

    # add columns to the dataframe (each one correspond to a different process from the list)
    for process in list_processes:
        df_temp = alg.compute_impacts([process],[ipcc2021], standalone = standalone, percentage_losses = 0, grid_loc = grid_list, mw_loc = mw_list)
        df_temp.rename(columns={'climate change - global warming potential (GWP100)[kg CO2-Eq]': str(process)}, inplace=True)
        merged_df = pd.merge(merged_df, df_temp, on='grid_loc')

    # change the name of the index 
    merged_df.rename(columns={'grid_loc': 'Location'}, inplace=True)
    merged_df['Location'] = countries
    merged_df.set_index('Location', inplace=True)
    new_df = merged_df.T

    #change index labels
    new_df.index = index_labels

    return new_df

# %%
alg.compute_impacts([EoL_pulp_biomed],[ipcc2021], standalone = 1,
                                            percentage_losses = 0,
                                            grid_loc = 'grid_SE',
                                            mw_loc = 'mw_RER')
# Out:
#                  climate change - global warming potential (GWP100)[kg CO2-Eq]
# EoL_pulp_biomed                                          0.0523183

# %%
list_processes_bioref = [lipophilic_extraction, sugar_extraction_withlosses, pulping_withlosses, heat_burdens, heat_residues, 
                         EoL_pulp_biomed, EoL_pulp_textile, EoL_pulp_nanocomposite, EoL_phenol_auto, EoL_phenol_construction,
                         EoL_phenol_furniture, EoL_phenol_electronics, EoL_phenol_others, EoL_starch_cardboard, EoL_talloil_biofuel,
                         talloil_sub, starch_sub, phenol_sub, pulp_sub]

index_labels_bioref = ['lipophilic extraction', 'sugar extraction', 'pulping', 'heat (burd.)', 'heat (RB)','EoL_pulp_biomed',
                        'EoL_pulp_textile', 'EoL_pulp_nanocomposite', 'EoL_phenol_auto', 'EoL_phenol_construction',  
                        'EoL_phenol_furniture', 'EoL_phenol_electronics', 'EoL_phenol_others', 'EoL_starch_cardboard', 
                        'EoL_talloil_biofuel', 'tall oil (sub.)', 'starch (sub.)', 'phenol (sub.)', 'pulp (sub.)']

list_processs_combustion = [heat_CHP_bark_scaled]
index_labels_combustion = ['heat_CHP_bark']

countries = ['SE','NO', 'FI', 'DK', 'FR', 'DE', 'BE', 'LU', 'NL', 'AT', 'RER']

grid_list = ['grid_SE', 'grid_NO', 'grid_FI', 'grid_DK', 'grid_FR', 'grid_DE', 'grid_BE', 'grid_LU', 'grid_NL', 'grid_AT', 'grid_RER']
mw_list = ['mw_SE', 'mw_NO', 'mw_FI', 'mw_DK', 'mw_FR', 'mw_DE', 'mw_BE', 'mw_LU', 'mw_NL', 'mw_AT', 'mw_RER']

# %%
# generate the dataframes
df_geoloc_standalone = sensitivity_geoloc(list_processes_bioref, index_labels_bioref, countries, standalone=1)
df_geoloc_integrated = sensitivity_geoloc(list_processes_bioref, index_labels_bioref, countries, standalone=0)
df_geoloc_combustion = sensitivity_geoloc(list_processs_combustion, index_labels_combustion, countries, standalone = 0)

# add a column with the EoL years
df_geoloc_standalone['Year']=[35, 35, 35, 35, 35, 36, 40, 55, 48, 85, 50, 42, 56, 36, 36, 35, 35, 35, 35]
df_geoloc_integrated['Year']=[35, 35, 35, 35, 35, 36, 40, 55, 48, 85, 50, 42, 56, 36, 36, 35, 35, 35, 35]
df_geoloc_combustion['Year'] = [35]

# add a column with the chracterisation factors corresponding to the specific year
df_geoloc_standalone['CF_CO2']=df_geoloc_standalone.apply(lambda row: f(row['Year']), axis=1)
df_geoloc_integrated['CF_CO2']=df_geoloc_integrated.apply(lambda row: f(row['Year']), axis=1)
df_geoloc_combustion['CF_CO2'] =df_geoloc_combustion.apply(lambda row: f(row['Year']), axis=1)

# recalculate the climate impacts for each column using the dCFs
for c in countries: 
    df_geoloc_standalone[c] = df_geoloc_standalone[c]*df_geoloc_standalone['CF_CO2']
    df_geoloc_integrated[c] = df_geoloc_integrated[c]*df_geoloc_integrated['CF_CO2']
    df_geoloc_combustion[c] = df_geoloc_combustion[c]*df_geoloc_combustion['CF_CO2']

# %%
df_geoloc_standalone
# Out:
# Location                          SE          NO          FI           DK  \
# lipophilic extraction       0.320012   0.0481886    0.425227    0.0668517
# sugar extraction            0.642239   0.0852236    0.857843     0.123468
# pulping                     0.251501    0.136756    0.295915     0.144634
# heat (burd.)              -0.0707303  0.00117121  -0.0985588  -0.00376832
# heat (RB)                 -0.0155262 0.000257096  -0.0216349 -0.000827191
# EoL_pulp_biomed         -6.41967e-05   0.0138431 0.000925443   0.00528031
# EoL_pulp_textile        -6.10342e-05   0.0131612 0.000879854   0.00502019
# EoL_pulp_nanocomposite  -4.85641e-05   0.0104722 0.000700088    0.0039945
# EoL_phenol_auto         -2.71294e-05  0.00585008 0.000391091   0.00223145
# EoL_phenol_construction -5.48413e-06  0.00118257 7.90579e-05  0.000451082
# EoL_phenol_furniture    -1.18332e-05  0.00255166 0.000170584  0.000973306
# EoL_phenol_electronics  -1.03507e-05  0.00223198 0.000149213  0.000851368
# EoL_phenol_others       -2.96644e-06  0.00063967 4.27634e-05  0.000243996
# EoL_starch_cardboard    -0.000103351   0.0222862  0.00148989   0.00850087
# EoL_talloil_biofuel     -9.39558e-06  0.00202602 0.000135444  0.000772806
# tall oil (sub.)           -0.0261015  -0.0261015  -0.0261015   -0.0261015
# starch (sub.)              -0.263191   -0.263191   -0.263191    -0.263191
# phenol (sub.)              -0.286139   -0.286139   -0.286139    -0.286139
# pulp (sub.)                0.0198746   0.0198746   0.0198746    0.0198746
#
# Location                          FR          DE           BE         LU  \
# lipophilic extraction      0.0654045     0.24875     0.477557   0.594551
# sugar extraction            0.120502    0.496211     0.965078    1.20482
# pulping                     0.144023    0.221419     0.318006   0.367392
# heat (burd.)              -0.0033778  -0.0518814    -0.112401  -0.143333
# heat (RB)               -0.000741468  -0.0113886   -0.0246734 -0.0314633
# EoL_pulp_biomed            0.0259101  0.00106189  -0.00208192  0.0312771
# EoL_pulp_textile           0.0246337  0.00100958  -0.00197936  0.0297363
# EoL_pulp_nanocomposite     0.0196007 0.000803308  -0.00157495  0.0236608
# EoL_phenol_auto            0.0109496 0.000448753 -0.000879817  0.0132176
# EoL_phenol_construction   0.00221342 9.07141e-05 -0.000177852 0.00267191
# EoL_phenol_furniture      0.00477594 0.000195735 -0.000383755 0.00576522
# EoL_phenol_electronics     0.0041776 0.000171213 -0.000335677 0.00504294
# EoL_phenol_others         0.00119727 4.90684e-05 -9.62027e-05 0.00144527
# EoL_starch_cardboard       0.0417131  0.00170955  -0.00335172  0.0503535
# EoL_talloil_biofuel        0.0037921 0.000155414 -0.000304702 0.00457759
# tall oil (sub.)           -0.0261015  -0.0261015   -0.0261015 -0.0261015
# starch (sub.)              -0.263191   -0.263191    -0.263191  -0.263191
# phenol (sub.)              -0.286139   -0.286139    -0.286139  -0.286139
# pulp (sub.)                0.0198746   0.0198746    0.0198746  0.0198746
#
# Location                         NL          AT        RER  Year  \
# lipophilic extraction      0.150353    0.417195   0.404663    35
# sugar extraction           0.294577    0.841384   0.815703    35
# pulping                    0.179882    0.292525   0.287234    35
# heat (burd.)             -0.0258538  -0.0964342 -0.0931061    35
# heat (RB)               -0.00567522  -0.0211685 -0.0204379    35
# EoL_pulp_biomed          0.00602242  0.00138775  0.0368125    36
# EoL_pulp_textile         0.00572574  0.00131939  0.0349991    40
# EoL_pulp_nanocomposite    0.0045559  0.00104982  0.0278483    55
# EoL_phenol_auto          0.00254507 0.000586461  0.0155569    48
# EoL_phenol_construction 0.000514477 0.000118551 0.00314478    85
# EoL_phenol_furniture      0.0011101   0.0002558 0.00678555    50
# EoL_phenol_electronics  0.000971021 0.000223753 0.00593545    42
# EoL_phenol_others       0.000278288  6.4126e-05 0.00170106    56
# EoL_starch_cardboard     0.00969559  0.00223416  0.0592651    36
# EoL_talloil_biofuel     0.000881418 0.000203106 0.00538774    36
# tall oil (sub.)          -0.0261015  -0.0261015 -0.0261015    35
# starch (sub.)             -0.263191   -0.263191  -0.263191    35
# phenol (sub.)             -0.286139   -0.286139  -0.286139    35
# pulp (sub.)               0.0198746   0.0198746  0.0198746    35
#
# Location                              CF_CO2
# lipophilic extraction     0.7122005711971273
# sugar extraction          0.7122005711971273
# pulping                   0.7122005711971273
# heat (burd.)              0.7122005711971273
# heat (RB)                 0.7122005711971273
# EoL_pulp_biomed           0.7036265752217709
# EoL_pulp_textile            0.66896439364975
# EoL_pulp_nanocomposite    0.5322861270004348
# EoL_phenol_auto            0.597558947011865
# EoL_phenol_construction  0.21007773733486354
# EoL_phenol_furniture      0.5792014832551217
# EoL_phenol_electronics    0.6513918213505662
# EoL_phenol_others         0.5227154717668315
# EoL_starch_cardboard      0.7036265752217709
# EoL_talloil_biofuel       0.7036265752217709
# tall oil (sub.)           0.7122005711971273
# starch (sub.)             0.7122005711971273
# phenol (sub.)             0.7122005711971273
# pulp (sub.)               0.7122005711971273

# %%
# remove the columns that are not required anymore
df_geoloc_standalone = df_geoloc_standalone.drop(['Year', 'CF_CO2'], axis=1)
df_geoloc_integrated = df_geoloc_integrated.drop(['Year', 'CF_CO2'], axis=1)
df_geoloc_combustion = df_geoloc_combustion.drop(['Year', 'CF_CO2'], axis=1)

# calculate the total climate impacts (from indirect emissions only) for each geographical location (considering substitution effects)
df_geoloc_standalone.loc['Total']= df_geoloc_standalone.sum()
df_geoloc_integrated.loc['Total']= df_geoloc_integrated.sum()
df_geoloc_combustion.loc['Total']= df_geoloc_combustion.sum()

## keep the total row for each of the 3 scenarios 
total_df_list = [df_geoloc_standalone.loc['Total'], df_geoloc_integrated.loc['Total'], df_geoloc_combustion.loc['Total']]
df_merge_total = pd.merge(df_geoloc_standalone.loc['Total'], df_geoloc_integrated.loc['Total'], on='Location')
df_merge_total = pd.merge(df_merge_total, df_geoloc_combustion.loc['Total'], on='Location')
df_merge_total.rename(columns={'Total_x': 'Stand-alone biorefinery', 'Total_y': 'Integrated biorefinery', 'Total': 'Combustion'}, inplace=True)

# add the values for the direct emissions (remain constant no matter the geographical location)
df_merge_total['Stand-alone biorefinery'] = df_merge_total['Stand-alone biorefinery'] + dCF_df_direct_emissions.loc['Total']['Stand-alone biorefinery']
df_merge_total['Integrated biorefinery'] = df_merge_total['Integrated biorefinery'] + dCF_df_direct_emissions.loc['Total']['Integrated biorefinery']
df_merge_total['Combustion'] = df_merge_total['Combustion'] + dCF_df_direct_emissions.loc['Total']['Combustion']
df_merge_total
# Out:
#          Stand-alone biorefinery Integrated biorefinery Combustion
# Location
# SE                       1.71039               0.527608    1.21789
# NO                      0.929083               0.689882    1.30557
# FI                         2.047               0.498978    1.18395
# DK                       0.94192               0.637933    1.29955
# FR                       1.04802               0.749053    1.30002
# DE                       1.49205               0.556634    1.24087
# BE                       2.19564               0.465968    1.16707
# LU                       2.74295               0.607161    1.12935
# NL                       1.20883                0.61498    1.27261
# AT                       2.02419               0.504049    1.18654
# RER                      2.17474               0.698101     1.1906

# %% [markdown]
# **Note:** The values for SE do not correspond to the ones obtained to plot Fig.5 in the manuscript since the baseline scenario was defined using the Swedish grid mix for electricity consumption (grid_SE) and the European average for solid waste treatment (mw_RER). See the parameters defined in Section 6. In the dataframe generated above, SE corresponds to the use of the Swedish electricity mix and the Swedish solid waste treatment activity.

# %%
# Plotting the data
fig, ax = plt.subplots(figsize=(7, 5))

plt.scatter(df_merge_total.index, df_merge_total['Stand-alone biorefinery'], label='Stand-alone biorefinery', marker='o', color = '#332288', s=100)
plt.scatter(df_merge_total.index, df_merge_total['Integrated biorefinery'], label='Integrated biorefinery', marker='s', color = '#44AA99', s=100)
plt.scatter(df_merge_total.index, df_merge_total['Combustion'], label='Combustion', marker='^', color = '#CC6677', s=100)

# Adding titles and labels
plt.xlabel('Geographical location (country)', size =14)
plt.ylabel('Climate impacts (kg CO2-eq/FU)', size=14)
plt.legend(frameon=False, fontsize=14)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='x', labelsize=14, rotation=0)
ax.tick_params(axis='y', labelsize=14)

    
plt.tight_layout()
plt.savefig(str(result_dir+'/fig6_sensitivity_geoloc_'+ei+'.pdf'), dpi=300)


# Show plot
plt.show()

# %% [markdown]
# ## 9.3. Influence of the biomass losses
#
# A change in the percentage of biomass losses affects both the direct and indirect emissions for the biorefinery scenarios.

# %% [markdown]
# ### 9.3.1. Calculate the indirect emissions for the different percentages of losses

# %%
def sensitivity_biomass_losses (list_processes, index_labels, standalone):

    # create the initial dataframe with the % of biomass losses as the index
    merged_df = pd.DataFrame({'% losses': np.arange(0, 1, 0.1)})
    #merged_df = pd.DataFrame({'% losses': [0]})
    merged_df.set_index('% losses', inplace=True)
    
    # add columns to the dataframe (each one correspond to a different process from the list)
    for process in list_processes:
        df_temp = alg.compute_impacts([process],[ipcc2021], standalone = standalone, percentage_losses = np.arange(0, 1, 0.1), grid_loc = 'grid_SE', mw_loc = 'mw_RER')
        #df_temp = alg.compute_impacts([process],[ipcc2021], standalone = standalone, percentage_losses = 0, grid_loc = 'grid_SE', mw_loc = 'mw_RER')        
        df_temp['% losses']=np.arange(0, 1, 0.1)
        #df_temp['% losses']=[0]
        df_temp.set_index('% losses', inplace=True)
        df_temp.rename(columns={'climate change - global warming potential (GWP100)[kg CO2-Eq]': str(process)}, inplace=True)
        merged_df = pd.merge(merged_df, df_temp, on='% losses')
    
    new_df = merged_df.T
    
    #change index labels
    new_df.index = index_labels

    return new_df

# %%
list_processes_bioref = [lipophilic_extraction, sugar_extraction_withlosses, pulping_withlosses, heat_burdens, heat_residues, 
                         EoL_pulp_biomed, EoL_pulp_textile, EoL_pulp_nanocomposite, EoL_phenol_auto, EoL_phenol_construction,
                         EoL_phenol_furniture, EoL_phenol_electronics, EoL_phenol_others, EoL_starch_cardboard, EoL_talloil_biofuel,
                         talloil_sub, starch_sub, phenol_sub, pulp_sub]

index_labels_bioref = ['lipophilic extraction', 'sugar extraction', 'pulping', 'heat (burd.)', 'heat (RB)','EoL_pulp_biomed',
                        'EoL_pulp_textile', 'EoL_pulp_nanocomposite', 'EoL_phenol_auto', 'EoL_phenol_construction',  
                        'EoL_phenol_furniture', 'EoL_phenol_electronics', 'EoL_phenol_others', 'EoL_starch_cardboard', 
                        'EoL_talloil_biofuel', 'tall oil (sub.)', 'starch (sub.)', 'phenol (sub.)', 'pulp (sub.)']

list_processs_combustion = [heat_CHP_bark_scaled]
index_labels_combustion = ['heat_CHP_bark']

# %%
# generate the dataframes
df_losses_standalone = sensitivity_biomass_losses(list_processes_bioref, index_labels_bioref, standalone=1)
df_losses_integrated = sensitivity_biomass_losses(list_processes_bioref, index_labels_bioref, standalone=0)
df_losses_combustion = sensitivity_biomass_losses(list_processs_combustion, index_labels_combustion, standalone = 0)

# add a column with the EoL years
df_losses_standalone['Year']=[35, 35, 35, 35, 35, 36, 40, 55, 48, 85, 50, 42, 56, 36, 36, 35, 35, 35, 35]
df_losses_integrated['Year']=[35, 35, 35, 35, 35, 36, 40, 55, 48, 85, 50, 42, 56, 36, 36, 35, 35, 35, 35]
df_losses_combustion['Year'] = [35]

# add a column with the chracterisation factors corresponding to the specific year
df_losses_standalone['CF_CO2']=df_losses_standalone.apply(lambda row: f(row['Year']), axis=1)
df_losses_integrated['CF_CO2']=df_losses_integrated.apply(lambda row: f(row['Year']), axis=1)
df_losses_combustion['CF_CO2'] =df_losses_combustion.apply(lambda row: f(row['Year']), axis=1)

# recalculate the climate impacts for each column using the dCFs
for percentage in np.arange(0, 1, 0.1): 
    df_losses_standalone[percentage] = df_losses_standalone[percentage]*df_losses_standalone['CF_CO2']
    df_losses_integrated[percentage] = df_losses_integrated[percentage]*df_losses_integrated['CF_CO2']
    df_losses_combustion[percentage] = df_losses_combustion[percentage]*df_losses_combustion['CF_CO2']

#for percentage in np.arange(-1, 1, 0.1): 
# df_losses_standalone[0] = df_losses_standalone[0]*df_losses_standalone['CF_CO2']
# df_losses_integrated[0] = df_losses_integrated[0]*df_losses_integrated['CF_CO2']
# df_losses_combustion[0] = df_losses_combustion[0]*df_losses_combustion['CF_CO2']

# %%
# remove the columns that are not required anymore
df_losses_standalone = df_losses_standalone.drop(['Year', 'CF_CO2'], axis=1)
df_losses_integrated = df_losses_integrated.drop(['Year', 'CF_CO2'], axis=1)
df_losses_combustion = df_losses_combustion.drop(['Year', 'CF_CO2'], axis=1)

# calculate the total climate impacts (from indirect emissions only) for each geographical location (considering substitution effects)
df_losses_standalone.loc['Total']= df_losses_standalone.sum()
df_losses_integrated.loc['Total']= df_losses_integrated.sum()
df_losses_combustion.loc['Total']= df_losses_combustion.sum()

## keep the total row for each of the 3 scenarios 
total_df_list = [df_losses_standalone.loc['Total'], df_losses_integrated.loc['Total'], df_losses_combustion.loc['Total']]
df_merge_total = pd.merge(df_losses_standalone.loc['Total'], df_losses_integrated.loc['Total'], on='% losses')
df_merge_total = pd.merge(df_merge_total, df_losses_combustion.loc['Total'], on='% losses')
df_merge_total.rename(columns={'Total_x': 'Stand-alone biorefinery', 'Total_y': 'Integrated biorefinery', 'Total': 'Combustion'}, inplace=True)
final_indirect_emissions_df = df_merge_total
# Out:
# /tmp/ipykernel_85872/359115543.py:13: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   df_merge_total = pd.merge(df_losses_standalone.loc['Total'], df_losses_integrated.loc['Total'], on='% losses')

# %%
final_indirect_emissions_df
# Out:
#          Stand-alone biorefinery Integrated biorefinery Combustion
# % losses
# 0                       0.769392              -0.413394 -0.0862396
# 0.1                     0.777253              -0.405533 -0.0862396
# 0.2                     0.785114              -0.397672 -0.0862396
# 0.3                     0.792976              -0.389811 -0.0862396
# 0.4                     0.800837               -0.38195 -0.0862396
# 0.5                     0.808698              -0.374088 -0.0862396
# 0.6                     0.816559              -0.366227 -0.0862396
# 0.7                      0.82442              -0.358366 -0.0862396
# 0.8                     0.832282              -0.350505 -0.0862396
# 0.9                     0.840143              -0.342644 -0.0862396

# %% [markdown]
# ### 9.3.2. Calculate the direct emissions for the different percentages of losses

# %%
dCF_df_direct_emissions_copy = CO2_emissions_df.copy()

# %%
dCF_df_direct_emissions_copy
# Out:
#                          Stand-alone biorefinery  Integrated biorefinery  \
# Product
# residual biomass                        0.228201                0.228201
# EoL_pulp_biomed                         0.214475                0.214475
# EoL_pulp_textile                        0.214475                0.214475
# EoL_pulp_nanocomposite                  0.214475                0.214475
# EoL_phenol_auto                         0.220567                0.220567
# EoL_phenol_construction                 0.126835                0.126835
# EoL_phenol_furniture                   0.0992735               0.0992735
# EoL_phenol_electronics                 0.0772168               0.0772168
# EoL_phenol_others                      0.0275617               0.0275617
# EoL_starch_cardboard                     0.35221                 0.35221
# EoL_talloil_biofuel                     0.055784                0.055784
# heat CHP bark                                NaN                     NaN
#
#                          Combustion  Year
# Product
# residual biomass                NaN    35
# EoL_pulp_biomed                 NaN    36
# EoL_pulp_textile                NaN    40
# EoL_pulp_nanocomposite          NaN    55
# EoL_phenol_auto                 NaN    48
# EoL_phenol_construction         NaN    85
# EoL_phenol_furniture            NaN    50
# EoL_phenol_electronics          NaN    42
# EoL_phenol_others               NaN    56
# EoL_starch_cardboard            NaN    36
# EoL_talloil_biofuel             NaN    36
# heat CHP bark               1.83115    35

# %%
final_direct_emissions_df = pd.DataFrame(columns=['Stand-alone biorefinery','Integrated biorefinery','Combustion'])

for losses in np.arange(0, 1, 0.1):
#for losses in [0]:    
    # copy the dataframe
    dCF_df_direct_emissions_copy = CO2_emissions_df.copy()
    
    # transform the dataframe into a dictionary
    dict_emissions = CO2_emissions_df.to_dict('dict')
    
    # make a copy 
    new_dict_emissions = dict_emissions.copy()

    # calculate the new values for the direct emissions
    # for scenario in dict_emissions.keys():
    #     # update the values for the biorefinery scenarios only
    #     if scenario == 'Stand-alone biorefinery' or scenario == 'Integrated biorefinery':
    #         for process in dict_emissions[scenario].keys():
    #             # if the losses increase, then there is more residual biomass
    #             if process == 'residual biomass':
    #                 new_dict_emissions[scenario][process] = new_dict_emissions[scenario][process] * (1+losses)
    #             else: 
    #                 # if the losses increase, then there is less products
    #                 new_dict_emissions[scenario][process] = new_dict_emissions[scenario][process] * (1-losses)

    for scenario in dict_emissions.keys():
        # update the values for the biorefinery scenarios only (not the combustion)
        if scenario == 'Stand-alone biorefinery' or scenario == 'Integrated biorefinery':
            for process in dict_emissions[scenario].keys():
                # if the losses increase, then there is more residual biomass
                if process == 'residual biomass':
                    new_dict_emissions[scenario][process] = new_dict_emissions[scenario][process] * (1+losses)
                else: 
                    # if the losses increase, then there is less products
                    #new_dict_emissions[scenario][process] = new_dict_emissions[scenario][process] * (1-losses)
                    new_dict_emissions[scenario][process] = (new_dict_emissions[scenario][process]/(1.83-0.228201))*(1.83-0.228201*(1+losses))

    new_df_emissions = pd.DataFrame(new_dict_emissions)

    # add the dCFs that correspond to the specific years
    new_df_emissions['CF_CO2'] = new_df_emissions.apply(lambda row: f(row['Year']), axis=1)

    # calculated the climate impacts using the dCFs
    new_df_emissions['Stand-alone biorefinery'] = new_df_emissions['Stand-alone biorefinery']*new_df_emissions['CF_CO2']
    new_df_emissions['Integrated biorefinery'] = new_df_emissions['Integrated biorefinery']*new_df_emissions['CF_CO2']
    new_df_emissions['Combustion'] = new_df_emissions['Combustion']*new_df_emissions['CF_CO2']
    
    # remove the columns that are not needed anymore
    new_df_emissions = new_df_emissions.drop(['Year', 'CF_CO2'], axis=1)

    # calculate the total climate impacts
    new_df_emissions.loc['Total']= new_df_emissions.sum()

    # only keep the total column and add it into a new dataframe, rename the row with the corresponding % losses
    final_direct_emissions_df.loc[losses]=new_df_emissions.loc['Total']

final_direct_emissions_df['% losses']=np.arange(0, 1, 0.1)
final_direct_emissions_df.set_index('% losses', inplace=True)
# final_direct_emissions_df['% losses']=[0]
# final_direct_emissions_df.set_index('% losses', inplace=True)

# %%
final_direct_emissions_df
# Out:
#          Stand-alone biorefinery Integrated biorefinery Combustion
# % losses
# 0                         1.1388                 1.1388    1.30414
# 0.1                      1.14114                1.14114    1.30414
# 0.2                      1.14349                1.14349    1.30414
# 0.3                      1.14583                1.14583    1.30414
# 0.4                      1.14818                1.14818    1.30414
# 0.5                      1.15052                1.15052    1.30414
# 0.6                      1.15286                1.15286    1.30414
# 0.7                      1.15521                1.15521    1.30414
# 0.8                      1.15755                1.15755    1.30414
# 0.9                       1.1599                 1.1599    1.30414

# %% [markdown]
# ### 9.3.3. Calculate the total emissions for the different percentages of losses

# %%
# add the values of the two dataframes to get the total values
total_emissions_df = final_indirect_emissions_df + final_direct_emissions_df
total_emissions_df
# Out:
#          Stand-alone biorefinery Integrated biorefinery Combustion
# % losses
# 0                        1.90819               0.725406     1.2179
# 0.1                       1.9184               0.735611     1.2179
# 0.2                       1.9286               0.745816     1.2179
# 0.3                      1.93881               0.756021     1.2179
# 0.4                      1.94901               0.766226     1.2179
# 0.5                      1.95922               0.776431     1.2179
# 0.6                      1.96942               0.786636     1.2179
# 0.7                      1.97963               0.796841     1.2179
# 0.8                      1.98983               0.807046     1.2179
# 0.9                      2.00004               0.817251     1.2179

# %%
import matplotlib.pyplot as plt

# Plotting the data
fig, ax = plt.subplots(figsize=(7, 5))

# Plot continuous lines
plt.plot(total_emissions_df.index, total_emissions_df['Stand-alone biorefinery'], 
         label='Stand-alone biorefinery', color='#332288', linestyle='-', linewidth=3.5)
plt.plot(total_emissions_df.index, total_emissions_df['Integrated biorefinery'], 
         label='Integrated biorefinery', color='#44AA99', linestyle='-', linewidth=3.5)
plt.plot(total_emissions_df.index, total_emissions_df['Combustion'], 
         label='Combustion', color='#CC6677', linestyle='-', linewidth=3.5)

# Adding titles and labels
plt.xlabel('Biomass losses (%)', size=14)
plt.ylabel('Climate impacts (kg CO2-eq/FU)', size=14)
#plt.legend(frameon=False, fontsize=14, loc='lower center', bbox_to_anchor=(0.7, 0.48))
plt.legend(frameon=False, fontsize=14, loc='upper right', bbox_to_anchor=(1, 0.8))


# Customize axes
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='x', labelsize=14, rotation=0)
ax.tick_params(axis='y', labelsize=14)

# Save and show plot
plt.tight_layout()
plt.savefig(str(result_dir+'/fig6_sensitivity_losses_'+ei+'.pdf'), dpi=300)

plt.show()

# %% [markdown]
# ## 9.4. Influence of the background data
#
# The choice of the background database influences the calculation of the indirect emissions. To perform this sensitivity analysis, the code above needs to be run until the end of Section 8.3, for each of the background databases. The results obtained are stored in Excel files that are imported below to plot the sensisitvity analysis graph.

# %%
# import the data from the Excel files
df_ei39 = pd.read_excel(str(result_dir+'/total_climate_impacts_DCFs_ecoinvent_3.9_conseq.xlsx'))
df_ei39_REMIND_SSP2_Base = pd.read_excel(str(result_dir+'/total_climate_impacts_DCFs_ecoinvent_consequential_3.9_remind_SSP2-Base_2045.xlsx'))
df_ei39_REMIND_SSP2_PkBudg500 = pd.read_excel(str(result_dir+'/total_climate_impacts_DCFs_ecoinvent_consequential_3.9_remind_SSP2-PkBudg500_2045.xlsx'))
df_ei39_REMIND_SSP1_PkBudg500 = pd.read_excel(str(result_dir+'/total_climate_impacts_DCFs_ecoinvent_consequential_3.9_remind_SSP1-PkBudg500_2045.xlsx'))
df_ei39_IMAGE_SSP2_Base = pd.read_excel(str(result_dir+'/total_climate_impacts_DCFs_ecoinvent_consequential_3.9_remind_SSP2-Base_2045.xlsx'))

df_list = [df_ei39, df_ei39_REMIND_SSP2_PkBudg500, df_ei39_REMIND_SSP1_PkBudg500, df_ei39_REMIND_SSP2_Base, df_ei39_IMAGE_SSP2_Base]
db_names = ['Conventional', 'REMIND-SSP2-PkBudg500-2045', 'REMIND-SSP1-PkBudg500-2045', 'REMIND-SSP2-Base-2045','IMAGE-SSP2-Base-2045']

df_total_climate_impacts = pd.DataFrame(columns=['Stand-alone\nbiorefinery','Integrated\nbiorefinery','Combustion'])

for i in range(len(df_list)):
    df = df_list[i]
    # reset the index
    df = df.set_index('Unnamed: 0')
    # calculate the total value
    df.loc['Total'] = df.sum()
    # add the total into the new dataframe
    df_total_climate_impacts.loc[db_names[i]] = df.loc['Total'] 

df_total_climate_impacts
# Out:
#                             Stand-alone\nbiorefinery  Integrated\nbiorefinery  \
# Conventional                                 1.90819                 0.725406
# REMIND-SSP2-PkBudg500-2045                   1.09578                 0.850325
# REMIND-SSP1-PkBudg500-2045                   1.07731                 0.852649
# REMIND-SSP2-Base-2045                        1.02484                 0.757394
# IMAGE-SSP2-Base-2045                         1.02484                 0.757394
#
#                             Combustion
# Conventional                    1.2179
# REMIND-SSP2-PkBudg500-2045     1.30547
# REMIND-SSP1-PkBudg500-2045     1.30761
# REMIND-SSP2-Base-2045           1.3041
# IMAGE-SSP2-Base-2045            1.3041

# %%
# Marker styles and colors for different models
markers = ['o', 's', '^', 'D', 'p']
colors = ['#332288', '#44AA99', '#88CCEE', '#DDCC77', '#CC6677']
scenarios= ['Stand-alone\nbiorefinery','Integrated\nbiorefinery','Combustion']

# Create figure and axis
fig, ax = plt.subplots(figsize=(7,5))

# Set the positions of the x-ticks with reduced spacing
x_positions = (np.arange(len(scenarios))*4)  # Reduced spacing

# Plotting data points for each model in all scenarios
for j, db in enumerate(db_names):
    x_coords = []
    y_coords = []
    for i, scenario in enumerate(scenarios):
        x_coords.append(x_positions[i])  # Adjusted x-axis position
        y_coords.append(df_total_climate_impacts[scenario][db])  # Corresponding y-value for the model

    # Plot each model with a unique marker and color
    plt.scatter(x_coords, y_coords, marker=markers[j], facecolor = 'None',edgecolor=colors[j], s=100, label=db, linewidths=3)
    #plt.scatter(x_coords, y_coords, marker=markers[j], color=colors[j], s=100, label=model)

# Set labels and title#
plt.xticks(ticks=x_positions, labels=scenarios, size=14)
ax.set_xlim(-1.5,10)
#plt.xlabel("Scenarios")
plt.ylabel("Climate impact (kg CO2-eq/FU)", size = 14)
#plt.title("Scatter Plot of Different Scenarios and Models")

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(axis='x', labelsize=14, rotation=0)
ax.tick_params(axis='y', labelsize=14)

# Add legend for models, with a smaller font size and adjusted position
plt.legend(frameon=False,bbox_to_anchor=(0.98, 0.98), loc='upper right', fontsize=14)

# Show grid
#plt.grid(True)

# Adjust layout to make room for the legend
plt.tight_layout()
plt.savefig(str(result_dir+'/fig6_sensitivity_background_'+ei+'.pdf'), dpi=300)

# Show the plot
plt.show()

# %% [markdown]
# ## 9.5. Influence of the biogenic carbon content
#
# The biogenic carbon content of bark influences the calculation of direct CO2-eq emissions only. The indirect emissions remain similar as it was assumed that the mass balance remains unchanged. A decrease in the carbon content of bark is associated with n increase in the ash or water content of the biomass.

# %%
percentage_change_list = np.arange(-0.2, 0.2,0.01).tolist()
#percentage_change_list = [0]
GWP_standalone = []
GWP_integrated = []
GWP_combustion = []

for value in percentage_change_list:
    GWP_standalone.append(dCF_df.loc['Total']['Stand-alone biorefinery'] + dCF_df_direct_emissions.loc['Total']['Stand-alone biorefinery']*(1+value))
    GWP_integrated.append(dCF_df.loc['Total']['Integrated biorefinery'] + dCF_df_direct_emissions.loc['Total']['Integrated biorefinery']*(1+value))
    GWP_combustion.append(dCF_df.loc['Total']['Combustion'] + dCF_df_direct_emissions.loc['Total']['Combustion']*(1+value))

# %%
import matplotlib.pyplot as plt

# Plotting the data
fig, ax = plt.subplots(figsize=(7, 5))

# Plot continuous lines
plt.plot(percentage_change_list, GWP_standalone, 
         label='Stand-alone biorefinery', color='#332288', linestyle='-', linewidth=3.5)
plt.plot(percentage_change_list, GWP_integrated, 
         label='Integrated biorefinery', color='#44AA99', linestyle='-', linewidth=3.5)
plt.plot(percentage_change_list, GWP_combustion, 
         label='Combustion', color='#CC6677', linestyle='-', linewidth=3.5)

# Adding titles and labels
plt.xlabel('Change of bark biogenic carbon content (%)', size=14)
plt.ylabel('Climate impacts (kg CO2-eq/FU)', size=14)
plt.legend(frameon=False, fontsize=14, loc='lower center', bbox_to_anchor=(0.28, 0.8))

# Customize axes
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='x', labelsize=14, rotation=0)
ax.tick_params(axis='y', labelsize=14)

# Save and show plot
plt.tight_layout()
plt.savefig(str(result_dir+'/fig6_sensitivity_bioC_'+ei+'.pdf'), dpi=300)

plt.show()

# %% [markdown]
# # 10. Calculate the impacts for other impact categories using ReCiPe

# %%
recipe_all = alg.findMethods('ReCiPe 2016 v1.03, midpoint (H)')
recipe = recipe_all[18:36] # remove all the "no LT" impact categories
recipe_noGWP = [ic for ic in recipe if 'climate change' not in ic]
len(recipe_noGWP)
# Out:
# 17

# %%
df_bioref_standalone_allICs = alg.compute_impacts([lipophilic_extraction, 
                                            sugar_extraction_withlosses, 
                                            pulping_withlosses, 
                                            heat_burdens, 
                                            #processA, 
                                            #processB, 
                                            #processC, 
                                            heat_residues, 
                                            # EoL
                                            EoL_pulp_biomed,
                                            EoL_pulp_textile, 
                                            EoL_pulp_nanocomposite,
                                            EoL_phenol_auto, 
                                            EoL_phenol_construction, 
                                            EoL_phenol_furniture, 
                                            EoL_phenol_electronics, 
                                            EoL_phenol_others, 
                                            EoL_starch_cardboard, 
                                            EoL_talloil_biofuel,                                   
                                            # substitution
                                            talloil_sub,
                                            starch_sub,
                                            phenol_sub, 
                                            pulp_sub],
                                            # lcia method
                                            recipe_noGWP,
                                            # parameters
                                            standalone = 1,
                                            percentage_losses = 0,
                                            grid_loc = 'grid_SE',
                                            mw_loc = 'mw_RER'
                                          )
df_bioref_standalone_allICs.to_excel(str(result_dir+"/all_impacts_recipe_standalone_bioref_" + str(ei)+ ".xlsx"))

# %%
df_bioref_integrated_allICs = alg.compute_impacts([lipophilic_extraction, 
                                            sugar_extraction_withlosses, 
                                            pulping_withlosses, 
                                            heat_burdens, 
                                            #processA, 
                                            #processB, 
                                            #processC, 
                                            heat_residues, 
                                            # EoL
                                            EoL_pulp_biomed,
                                            EoL_pulp_textile, 
                                            EoL_pulp_nanocomposite,
                                            EoL_phenol_auto, 
                                            EoL_phenol_construction, 
                                            EoL_phenol_furniture, 
                                            EoL_phenol_electronics, 
                                            EoL_phenol_others, 
                                            EoL_starch_cardboard, 
                                            EoL_talloil_biofuel,                                   
                                            # substitution
                                            talloil_sub,
                                            starch_sub,
                                            phenol_sub, 
                                            pulp_sub],
                                            # lcia method
                                            recipe_noGWP,
                                            # parameters
                                            standalone = 0,
                                            percentage_losses = 0,
                                            grid_loc = 'grid_SE',
                                            mw_loc = 'mw_RER'
                                          )
df_bioref_integrated_allICs.to_excel(str(result_dir+"/all_impacts_recipe_integrated_bioref_" + str(ei)+ ".xlsx"))

# %%
df_combustion_allICs = alg.compute_impacts([heat_CHP_bark_scaled],
                            recipe_noGWP,
                            # parameters
                            percentage_losses = 0,
                            grid_loc = 'grid_SE',
                            mw_loc = 'mw_RER'
                            )
df_combustion_allICs.to_excel(str(result_dir+"/all_impacts_recipe_integrated_combustion_" + str(ei)+ ".xlsx"))

# %%
ic_dict = {
    'water consumption potential' : {'name': 'water use - water consumption potential (WCP)[cubic meter]',
                                                 'unit': 'm3-Eq',
                                                 'abbrev': 'WCP'},
    'freshwater ecotoxicity potential' : {'name': 'ecotoxicity: freshwater - freshwater ecotoxicity potential (FETP)[kg 1,4-DCB-Eq]',
                                                 'unit': 'kg 1,4-DCB-Eq',
                                                 'abbrev': 'FETP'},
    'particulate matter formation':  {'name': 'particulate matter formation - particulate matter formation potential (PMFP)[kg PM2.5-Eq]',
                                                 'unit': 'kg PM2.5-Eq',
                                                 'abbrev': 'PMFP'},
    'human toxicity potential, carcinogenics':  {'name': 'human toxicity: carcinogenic - human toxicity potential (HTPc)[kg 1,4-DCB-Eq]',
                                                 'unit': 'kg 1,4-DCB-Eq',
                                                 'abbrev': 'HTPc'},
    'surplus ore potential' : {'name': 'material resources: metals/minerals - surplus ore potential (SOP)[kg Cu-Eq]',
                                                 'unit': 'kg Cu-Eq',
                                                 'abbrev': 'SOP'},
    'ionising radiation potential' : {'name': 'ionising radiation - ionising radiation potential (IRP)[kg Co-60-Eq]',
                                                 'unit': 'kg Co-60-Eq',
                                                 'abbrev': 'IRP'}
    }

# %%
def plot_ic (ic_name,ax): 

    # get the data
    name = ic_dict[ic_name]['name']
    df_ic_col_bioref_standalone = pd.DataFrame({'Stand-alone biorefinery': df_bioref_standalone_allICs[name]})
    df_ic_col_bioref_integrated = pd.DataFrame({'Integrated biorefinery': df_bioref_integrated_allICs[name]})
    df_ic_col_combustion = pd.DataFrame({'Combustion': df_combustion_allICs[name]})
    merged_df_table = pd.concat([df_ic_col_bioref_standalone, df_ic_col_bioref_integrated, df_ic_col_combustion], axis = 1)

    # get the total scores
    total_scores = list(merged_df_table.sum())
    total_scores = ['%.4f' % elem for elem in total_scores]
    total_scores = [float(elem) for elem in total_scores] # the list items must be floats

    # aggregate the EoL values into a unique row
    total_df = merged_df_table.copy()
    total_df.loc['EoL']= total_df.iloc[5:15].sum()
    total_df_vf = total_df.drop(total_df.index[5:15])

    # move the EoL row up
    row_to_move = total_df_vf.iloc[[10]]
    total_df_vf = total_df_vf.drop(['EoL'])
    total_df_vf = pd.concat([total_df_vf.iloc[:5], row_to_move, total_df_vf.iloc[5:]])
    
    #change index labels
    index_labels = ['lipophilic extraction', 'sugar extraction', 'pulping', 'heat (burd.)', 'heat (RB)','EoL', 
                    'tall oil (sub.)', 'starch (sub.)', 'phenol (sub.)', 'pulp (sub.)', 'heat CHP bark']
    
    total_df_vf.index = index_labels
    total_df_vf.rename(columns={'Stand-alone biorefinery': 'Sta.', 'Integrated biorefinery': 'Int.', 'Combustion':'Comb.'}, inplace=True)

    # plot the graph
    ic_abbrev = ic_dict[ic_name]['abbrev']
    ic_unit = ic_dict[ic_name]['unit']
    
    df_transposed = total_df_vf.T
    
    bars = df_transposed.plot(kind='bar', stacked=True, ax=ax, color=colors, legend=False)
    ax.set_ylabel(str(ic_abbrev + ' (' +ic_unit+')'), fontsize=10)
    # ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), title_fontsize='10', fontsize='10', ncol=4)
    
    ax.tick_params(axis='x', labelsize=10, rotation=0)
    ax.tick_params(axis='y', labelsize=10)
    ax.tick_params(axis='x', which='both', bottom=False)  # Remove x-axis ticks
    
    ax.axhline(y=0, color='black', linestyle='-', linewidth=0.5)
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    
    # add the single GWP100 scores for each scenario
    categories_index = np.arange(len(new_names))
    ax.scatter(categories_index, total_scores, color='black', marker = 'H', zorder=5)

    import matplotlib.ticker as ticker
    formatter = ticker.ScalarFormatter(useMathText=True)
    formatter.set_powerlimits((-2, 2))
    ax.yaxis.set_major_formatter(formatter)
    ax.yaxis.get_offset_text().set_position((0.01, 1.02))
            
    
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))

    return by_label.values(), by_label.keys()

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

fig = plt.figure(constrained_layout=True,figsize = (10,5))

ncols = 3
nrows = len(ic_dict.keys()) // ncols
keys = list(ic_dict.keys())
new_names = ['Stand-alone\nbiorefinery', 'Integrated\nbiorefinery', 'Combustion']


spec = gridspec.GridSpec(ncols=ncols, nrows=nrows, figure=fig,hspace=0.1,wspace=0.1)

handles = []
labels = []

count = 0
for i in range(ncols):
    for j in range(nrows): # n

        ax = fig.add_subplot(spec[j, i])      

     
        plot_ic (keys[count],ax = ax)

        plt.draw()
        labels, handles = ax.get_legend_handles_labels()

        if count>0:
            handles.append(handles)
            labels.append(labels)

        count+=1
leg = fig.legend(labels,handles, loc='lower center',bbox_to_anchor=(0.5, -0.15),ncols = 6,frameon = False)

plt.tight_layout()

plt.savefig(str(result_dir+'/SM1_lcia_ICs_' + ei + '.pdf'), dpi=300,bbox_extra_artists=[leg,], bbox_inches='tight')

plt.show()
# Out:
# /tmp/ipykernel_85872/3285163598.py:34: UserWarning: Legend does not support handles for list instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   leg = fig.legend(labels,handles, loc='lower center',bbox_to_anchor=(0.5, -0.15),ncols = 6,frameon = False)
# /tmp/ipykernel_85872/3285163598.py:36: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /tmp/ipykernel_85872/3285163598.py:36: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
df_bioref_standalone_allICs.loc['Total'] = df_bioref_standalone_allICs.sum()
df_bioref_integrated_allICs.loc['Total'] = df_bioref_integrated_allICs.sum()
df_combustion_allICs.loc['Total'] = df_combustion_allICs.sum()

# %%
new_df = pd.DataFrame(columns=list(df_bioref_standalone_allICs.columns))
new_df.loc['Stand-alone\nbiorefinery']=df_bioref_standalone_allICs.loc['Total']
new_df.loc['Integrated\nbiorefinery']=df_bioref_integrated_allICs.loc['Total']
new_df.loc['Combustion']=df_combustion_allICs.loc['Total']
df_transp = new_df.T
df_transp.to_excel(str(result_dir+"/table3_all_impacts_recipe_" + str(ei)+ ".xlsx"))
df_transp
# Out:
#                                                     Stand-alone\nbiorefinery  \
# acidification: terrestrial - terrestrial acidif...               -0.00183072
# ecotoxicity: freshwater - freshwater ecotoxicit...                  0.392271
# ecotoxicity: marine - marine ecotoxicity potent...                  0.518376
# ecotoxicity: terrestrial - terrestrial ecotoxic...                   3.47673
# energy resources: non-renewable, fossil - fossi...                  0.210413
# eutrophication: freshwater - freshwater eutroph...              -0.000179391
# eutrophication: marine - marine eutrophication ...              -0.000506494
# human toxicity: carcinogenic - human toxicity p...                 0.0571943
# human toxicity: non-carcinogenic - human toxici...                   6.07015
# ionising radiation - ionising radiation potenti...                0.00137013
# land use - agricultural land occupation (LOP)[m...                 -0.596136
# material resources: metals/minerals - surplus o...               7.35331e-05
# ozone depletion - ozone depletion potential (OD...              -2.54988e-07
# particulate matter formation - particulate matt...               -0.00012581
# photochemical oxidant formation: human health -...                0.00207097
# photochemical oxidant formation: terrestrial ec...                0.00230344
# water use - water consumption potential (WCP)[c...                -0.0712833
#
#                                                     Integrated\nbiorefinery  \
# acidification: terrestrial - terrestrial acidif...               -0.0043722
# ecotoxicity: freshwater - freshwater ecotoxicit...                 0.237679
# ecotoxicity: marine - marine ecotoxicity potent...                 0.327409
# ecotoxicity: terrestrial - terrestrial ecotoxic...                 -4.47458
# energy resources: non-renewable, fossil - fossi...                -0.427146
# eutrophication: freshwater - freshwater eutroph...             -0.000314542
# eutrophication: marine - marine eutrophication ...             -0.000523093
# human toxicity: carcinogenic - human toxicity p...                0.0213239
# human toxicity: non-carcinogenic - human toxici...                   4.9288
# ionising radiation - ionising radiation potenti...               0.00111019
# land use - agricultural land occupation (LOP)[m...                 -1.48341
# material resources: metals/minerals - surplus o...              -0.00325266
# ozone depletion - ozone depletion potential (OD...             -1.76753e-06
# particulate matter formation - particulate matt...              -0.00107359
# photochemical oxidant formation: human health -...              -0.00134934
# photochemical oxidant formation: terrestrial ec...              -0.00121171
# water use - water consumption potential (WCP)[c...               -0.0764187
#
#                                                      Combustion
# acidification: terrestrial - terrestrial acidif...   0.00102449
# ecotoxicity: freshwater - freshwater ecotoxicit...   -0.0106867
# ecotoxicity: marine - marine ecotoxicity potent...   -0.0119362
# ecotoxicity: terrestrial - terrestrial ecotoxic...      0.73497
# energy resources: non-renewable, fossil - fossi...    -0.053681
# eutrophication: freshwater - freshwater eutroph... -1.07907e-06
# eutrophication: marine - marine eutrophication ... -5.88898e-07
# human toxicity: carcinogenic - human toxicity p...  -0.00153886
# human toxicity: non-carcinogenic - human toxici...     0.304944
# ionising radiation - ionising radiation potenti... -0.000280694
# land use - agricultural land occupation (LOP)[m...   -0.0826737
# material resources: metals/minerals - surplus o...   0.00010347
# ozone depletion - ozone depletion potential (OD...  3.48938e-07
# particulate matter formation - particulate matt...  0.000284446
# photochemical oxidant formation: human health -...   0.00123653
# photochemical oxidant formation: terrestrial ec...   0.00123929
# water use - water consumption potential (WCP)[c...  0.000734219
